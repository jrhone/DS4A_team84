# %% [markdown]
# # Does school funding impact students academic performance?
#
# <img src="images/education-header.jpg" width="900" />
#
#
#
# **Credit:**  [techxend](https://www.techxtend.com/site/content/education/)

# %%
# Load relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import warnings
import scipy.stats as st

#sns.set_theme(style="ticks", color_codes=True)


warnings.filterwarnings("ignore")  # Suppress all warnings

# %%
# read file
df = pd.read_csv('final_economic_merged.csv', index_col = 0)
df.head()
# Out:
#        District Code      Agency Name  Total Enrollment  Total Revenue  \
# 11111        61119.0  ALAMEDA UNIFIED           11159.0     96642000.0
# 7174         61119.0  ALAMEDA UNIFIED           11159.0     96642000.0
# 7173         61119.0  ALAMEDA UNIFIED           11159.0     96642000.0
# 7172         61119.0  ALAMEDA UNIFIED           11159.0     96642000.0
# 11109        61119.0  ALAMEDA UNIFIED           11159.0     96642000.0
#
#        Revenue per student                      Subgroup ID  \
# 11111              8660.45                Two or More Races
# 7174               8660.45  Asian or Asian/Pacific Islander
# 7173               8660.45  Asian or Asian/Pacific Islander
# 7172               8660.45  Asian or Asian/Pacific Islander
# 11109              8660.45                Two or More Races
#
#        Count Enrollment per ethnicity  County Code  Test Id  Mean Scale Score  \
# 11111                          1206.0          1.0      1.0       2574.514286
# 7174                           3722.0          1.0      1.0       2590.300000
# 7173                           3722.0          1.0      2.0       2600.685714
# 7172                           3722.0          1.0      2.0       2548.071429
# 11109                          1206.0          1.0      1.0       2410.766667
#
#              ...          Total Tested with Scores  \
# 11111        ...                            2660.0
# 7174         ...                            6146.0
# 7173         ...                            6181.0
# 7172         ...                            3591.0
# 11109        ...                             630.0
#
#        CAASPP Reported Enrollment  Students Tested  Students with Scores  \
# 11111                       388.0            380.0                 380.0
# 7174                        895.0            878.0                 878.0
# 7173                        895.0            883.0                 883.0
# 7172                        519.0            513.0                 513.0
# 11109                        60.0             60.0                  60.0
#
#        Total Standard Exceeded  Total Standard Met  \
# 11111                    182.0               111.0
# 7174                     419.0               299.0
# 7173                     458.0               240.0
# 7172                     134.0               167.0
# 11109                      5.0                 9.0
#
#        Total Standard Met and Above  Total Standard Nearly Met  \
# 11111                         293.0                       44.0
# 7174                          718.0                      106.0
# 7173                          698.0                      124.0
# 7172                          301.0                      131.0
# 11109                          14.0                       18.0
#
#        Total Standard Not Met      Disadvantaged
# 11111                    43.0  Not Disadvantaged
# 7174                     54.0  Not Disadvantaged
# 7173                     61.0  Not Disadvantaged
# 7172                     81.0      Disadvantaged
# 11109                    28.0      Disadvantaged
#
# [5 rows x 21 columns]

# %%
# columns present on the dataset
df.columns
# Out:
# Index(['District Code', 'Agency Name', 'Total Enrollment', 'Total Revenue',
#        'Revenue per student', 'Subgroup ID', 'Count Enrollment per ethnicity',
#        'County Code', 'Test Id', 'Mean Scale Score',
#        'Total Tested At Entity Level', 'Total Tested with Scores',
#        'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
#        'Total Standard Exceeded', 'Total Standard Met',
#        'Total Standard Met and Above', 'Total Standard Nearly Met',
#        'Total Standard Not Met', 'Disadvantaged'],
#       dtype='object')

# %%
#Converting all the assessment columns back to  percentage columns for exceeded, nearly met, not met to show completion results as percentage of test taken
df['Percentate Std Exceed'] =(df['Total Standard Exceeded']/df['Students Tested']*100).round(decimals=0)
df['Percentage Std Met'] =(100*df['Total Standard Met']/df['Students Tested']).round(decimals=0)
df['Percentage Std Nearly Met'] =(100*df['Total Standard Nearly Met']/df['Students Tested']).round(decimals=0)
df['Percentage Std Not Met'] =(100*df['Total Standard Not Met']/df['Students Tested']).round(decimals=0)
df['Percentage Std Met and Above'] =(100*df['Total Standard Met and Above']/df['Students Tested']).round(decimals=0)
#Percentage was multiplied by the students tested information and not the total enrollment information.
#Students tested in Math and Literacy can be the same students or different students, we don't have that information.
#we are adding the results of both exams, this can cause a duplicate in value of students tested, I will separate both datasets

# %%
df['Pass'] = df['Percentate Std Exceed'] + df['Percentage Std Met']
df['Fail'] = df['Percentage Std Nearly Met'] + df['Percentage Std Not Met']

# %%
# columns present on the dataset
df.columns
# Out:
# Index(['District Code', 'Agency Name', 'Total Enrollment', 'Total Revenue',
#        'Revenue per student', 'Subgroup ID', 'Count Enrollment per ethnicity',
#        'County Code', 'Test Id', 'Mean Scale Score',
#        'Total Tested At Entity Level', 'Total Tested with Scores',
#        'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
#        'Total Standard Exceeded', 'Total Standard Met',
#        'Total Standard Met and Above', 'Total Standard Nearly Met',
#        'Total Standard Not Met', 'Disadvantaged', 'Percentate Std Exceed',
#        'Percentage Std Met', 'Percentage Std Nearly Met',
#        'Percentage Std Not Met', 'Percentage Std Met and Above', 'Pass',
#        'Fail'],
#       dtype='object')

# %%
# checking unique ethinicities present in subgroup ID 
df['Subgroup ID'].unique()
# Out:
# array(['Two or More Races', 'Asian or Asian/Pacific Islander', 'Black',
#        'Hispanic', 'White', 'Hawaiian Nat./Pacific Isl.',
#        'American Indian/Alaska Native'], dtype=object)

# %%
# filtering for ethiniticies of interest
# Step 1: create list of the ethiniticies of interest
#list1 = ['White', 'Black', 'Hispanic', 'Asian or Pacific Islander', 'Two or More Races']

# Step 2: filter based on the list above
#df = df[df['Subgroup ID'].isin(list1)]
#df.head(5)

# %%
# filtering based on total enrollment
df = df[df['Total Enrollment'] != 0]
df = df[df['Total Enrollment'] > 250]

# need to filter out the 6 schools that have more students tested than enrolled

# %%
# checking total enrollment data
# we see that there's a wide number of students per district. 
# the smallest district has 251 students and the largest over 630,000 students
df['Total Enrollment'].describe()
# Out:
# count      8215.000000
# mean      13977.693974
# std       38996.903019
# min         251.000000
# 25%        2696.000000
# 50%        7066.000000
# 75%       15377.500000
# max      633621.000000
# Name: Total Enrollment, dtype: float64

# %%
df['Mean Scale Score'].describe()
# Out:
# count    8215.000000
# mean     2518.456294
# std        59.984766
# min      2327.700000
# 25%      2473.450000
# 50%      2512.533333
# 75%      2557.800000
# max      2775.200000
# Name: Mean Scale Score, dtype: float64

# %%
# checking revenue per student data
# we see that the average capiutal per student is around 9640
# the minimum is 0 and the max capital per student is over 77000 clearly an outlier - we need to fix these
df['Revenue per student'].describe()
# Out:
# count      8215.000000
# mean       9610.568426
# std        4565.493615
# min           0.000000
# 25%        7716.220000
# 50%        9512.710000
# 75%       11376.780000
# max      167709.580000
# Name: Revenue per student, dtype: float64

# %%
df.to_csv('dashboard_final_merged.csv',index = False, header=True)

# %%
# dataset containing school districts with over $20,000 revenue per student
df_high_funding = df[(df['Revenue per student'] > 20_000)]

# update the main dataset to not include schools with over 20k revenue per student nor zero revenue per student
df = df[(df['Revenue per student'] < 20_000)]
df = df[(df['Revenue per student'] != 0)]

print(df_high_funding.shape)
# Out:
# (106, 28)

# %%
# Checking what the dataset looks like now
df.shape
# Out:
# (7935, 28)

# %% [markdown]
# --------------------

# %% [markdown]
# # Dictrict size per enrollment

# %%
#Create a box plot to show the outliers on our data in regards of size.
plt.figure(figsize=(6,3))
sns.boxplot(df['Total Enrollment']),#orient='v')
plt.title('District Enrollment boxplot')
plt.show()

# %%
#We created 4 groups of districts by size of enrollment. 
large_districts_df = df[df['Total Enrollment'] >= 60_000]
medium_districts_df= df[(df['Total Enrollment'] < 60_000) & (df['Total Enrollment'] >= 30_000)]
small_districts_df = df[(df['Total Enrollment'] < 30_000) & (df['Total Enrollment'] >= 10_000)]
smaller_districts_df = df[(df['Total Enrollment'] < 10_000) & (df['Total Enrollment'] >= 5_000)]

# %% [markdown]
# ## We will firts look at large districts, distribution of students by ethnicity, and understand if there is any pattern on grades by ethnicity

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='Count Enrollment per ethnicity',y='Agency Name',hue='Subgroup ID',data=large_districts_df)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#We are looking at the schools and were are they in the revenue/score comparison
plt.figure(figsize=(10, 4))
sns.scatterplot(x='Revenue per student', y='Mean Scale Score', hue='Agency Name',data=large_districts_df)
plt.show()

# %%
colors = {
    "Black": "green",
    "Hispanic": "orange",
    "White": "red",
    "Asian or Asian/Pacific Islander": "purple",
    'Hawaiian Nat./Pacific Isl.': "blue",
    'American Indian/Alaska Native':"brown",
    'Two or More Races':'pink'
}
_, ax = plt.subplots()
for key, group in large_districts_df.groupby("Subgroup ID"):
    group.plot.scatter(ax=ax, x="Revenue per student", y="Mean Scale Score", label=key, color=colors[key])
ax.set_xlabel("Revenue per student (USD)")
ax.set_ylabel("Mean Scale Score")
_ = ax.set_title(
    "Large county revenue per student relationship to mean scale score"
)

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=large_districts_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score for Districts with more than 60K Students')

# %%
ld_corr_df= large_districts_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])

# %%
ld_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.509769          0.070509
# Revenue per student          0.509769             1.000000         -0.043934
# Mean Scale Score             0.070509            -0.043934          1.000000
# Pass                         0.050024            -0.066022          0.948222
# Fail                        -0.049895             0.066911         -0.947413
#
#                          Pass      Fail
# Total Enrollment     0.050024 -0.049895
# Revenue per student -0.066022  0.066911
# Mean Scale Score     0.948222 -0.947413
# Pass                 1.000000 -0.999505
# Fail                -0.999505  1.000000

# %%
#Scatter plot for each ethnicity.
ld_asian_df = large_districts_df[large_districts_df['Subgroup ID']=='Asian or Asian/Pacific Islander']
ld_black_df = large_districts_df[large_districts_df['Subgroup ID']=='Black']
ld_amerindian_df = large_districts_df[large_districts_df['Subgroup ID']=='American Indian/Alaska Native']
ld_hawaiian_df = large_districts_df[large_districts_df['Subgroup ID']=='Hawaiian Nat./Pacific Isl.']
ld_two_df = large_districts_df[large_districts_df['Subgroup ID']=='Black']
ld_hispanic_df = large_districts_df[large_districts_df['Subgroup ID']=='Hispanic']
ld_white_df = large_districts_df[large_districts_df['Subgroup ID']=='White']

# %%
def best_fit(X, Y):

    xbar = sum(X)/len(X)
    ybar = sum(Y)/len(Y)
    n = len(X) # or len(Y)

    numer = sum([xi*yi for xi,yi in zip(X, Y)]) - n * xbar * ybar
    denum = sum([xi**2 for xi in X]) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))

    return a, b
a, b = best_fit(ld_black_df['Revenue per student'],ld_black_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(ld_black_df['Revenue per student'],ld_black_df['Mean Scale Score'])
yfit = [a + b * xi for xi in ld_black_df['Revenue per student']]
plt.plot(ld_black_df['Revenue per student'], yfit)
plt.xlabel('Revenue per Student')
plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2462.46 + 0.00x
# Text(0,0.5,'Mean Scale Score')

# %%
a, b = best_fit(ld_white_df['Revenue per student'],ld_white_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(ld_white_df['Revenue per student'],ld_white_df['Mean Scale Score'])
yfit = [a + b * xi for xi in ld_white_df['Revenue per student']]
plt.plot(ld_white_df['Revenue per student'], yfit)
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2580.23 + -0.00x

# %%
white_corr_df= ld_white_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
white_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.486950         -0.027003
# Revenue per student          0.486950             1.000000         -0.212995
# Mean Scale Score            -0.027003            -0.212995          1.000000
# Pass                        -0.018290            -0.188366          0.978056
# Fail                         0.027472             0.197502         -0.974409
#
#                          Pass      Fail
# Total Enrollment    -0.018290  0.027472
# Revenue per student -0.188366  0.197502
# Mean Scale Score     0.978056 -0.974409
# Pass                 1.000000 -0.999357
# Fail                -0.999357  1.000000

# %%
a, b = best_fit(ld_hispanic_df['Revenue per student'],ld_hispanic_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(ld_hispanic_df['Revenue per student'],ld_hispanic_df['Mean Scale Score'])
yfit = [a + b * xi for xi in ld_hispanic_df['Revenue per student']]
plt.plot(ld_hispanic_df['Revenue per student'], yfit)
plt.title('Hispanic ethnicity Revenue - Mean Scale Score relationship to Revenue')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2494.28 + -0.00x

# %%
a, b = best_fit(ld_asian_df['Revenue per student'],ld_asian_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(ld_asian_df['Revenue per student'],ld_asian_df['Mean Scale Score'])
yfit = [a + b * xi for xi in ld_asian_df['Revenue per student']]
plt.plot(ld_asian_df['Revenue per student'], yfit)
plt.title('Asian or Pacific Islander ethnicity Revenue - Mean Scale Score relationship to Revenu')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2606.70 + -0.00x

# %%
asian_corr_df= ld_asian_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
asian_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.486950          0.272115
# Revenue per student          0.486950             1.000000         -0.285774
# Mean Scale Score             0.272115            -0.285774          1.000000
# Pass                         0.221863            -0.287062          0.952840
# Fail                        -0.222290             0.279380         -0.953568
#
#                          Pass      Fail
# Total Enrollment     0.221863 -0.222290
# Revenue per student -0.287062  0.279380
# Mean Scale Score     0.952840 -0.953568
# Pass                 1.000000 -0.999102
# Fail                -0.999102  1.000000

# %%
a, b = best_fit(ld_amerindian_df['Revenue per student'],ld_amerindian_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(ld_amerindian_df['Revenue per student'],ld_amerindian_df['Mean Scale Score'])
yfit = [a + b * xi for xi in ld_amerindian_df['Revenue per student']]
plt.plot(ld_amerindian_df['Revenue per student'], yfit)
plt.title('American Indian/Alaka Native Revenue - Mean Scale Score relationship to Revenue')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2448.83 + 0.00x

# %%
amerindian_corr_df= ld_amerindian_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
amerindian_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.630894          0.351594
# Revenue per student          0.630894             1.000000          0.203286
# Mean Scale Score             0.351594             0.203286          1.000000
# Pass                         0.135602            -0.345633          0.707254
# Fail                        -0.139947             0.350023         -0.701433
#
#                          Pass      Fail
# Total Enrollment     0.135602 -0.139947
# Revenue per student -0.345633  0.350023
# Mean Scale Score     0.707254 -0.701433
# Pass                 1.000000 -0.999511
# Fail                -0.999511  1.000000

# %%
white_corr_df= ld_white_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
white_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.486950         -0.027003
# Revenue per student          0.486950             1.000000         -0.212995
# Mean Scale Score            -0.027003            -0.212995          1.000000
# Pass                        -0.018290            -0.188366          0.978056
# Fail                         0.027472             0.197502         -0.974409
#
#                          Pass      Fail
# Total Enrollment    -0.018290  0.027472
# Revenue per student -0.188366  0.197502
# Mean Scale Score     0.978056 -0.974409
# Pass                 1.000000 -0.999357
# Fail                -0.999357  1.000000

# %%
a, b = best_fit(ld_two_df['Revenue per student'],ld_two_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(ld_two_df['Revenue per student'],ld_two_df['Mean Scale Score'])
yfit = [a + b * xi for xi in ld_two_df['Revenue per student']]
plt.plot(ld_two_df['Revenue per student'], yfit)
plt.title('Two or more races - Mean Scale Score relationship to Revenue')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2462.46 + 0.00x

# %% [markdown]
# ### It seems that revenue per student has a negative correlation to Mean Scale score or students passing. As we noted on each of the different ethnicities it would seem the larger the revenue per student the lower test scores, whith the highest impact on ethnicities - American Indian/Alaska Native, White and Asian or Pacific Islander.

# %% [markdown]
# # Medium size Districts analysis

# %%
_ = plt.hist(medium_districts_df['Revenue per student'], density=False, bins=30)
_ = plt.ylabel('Number of ocurrences')
_ = plt.xlabel('Revenue')
_ = plt.title("Revenue per Student")

# %% [markdown]
# ### FIND SOME BETTER WAY TO SHOW THIS

# %%
#Which is the ethnicity precence on each of these schools
plt.figure(figsize=(6, 4))
sns.barplot(x='Count Enrollment per ethnicity',y='Agency Name',hue='Subgroup ID',data=medium_districts_df)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
a, b = best_fit(medium_districts_df['Revenue per student'],medium_districts_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(medium_districts_df['Revenue per student'],medium_districts_df['Mean Scale Score'])
yfit = [a + b * xi for xi in medium_districts_df['Revenue per student']]
plt.plot(medium_districts_df['Revenue per student'], yfit)
plt.title('Mean Scale Score relationship to Revenue for 30-60K Students')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2575.77 + -0.01x

# %%
medium_corr_df= medium_districts_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
medium_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.069334         -0.015143
# Revenue per student          0.069334             1.000000         -0.257458
# Mean Scale Score            -0.015143            -0.257458          1.000000
# Pass                        -0.009894            -0.309557          0.847862
# Fail                         0.011858             0.309205         -0.848379
#
#                          Pass      Fail
# Total Enrollment    -0.009894  0.011858
# Revenue per student -0.309557  0.309205
# Mean Scale Score     0.847862 -0.848379
# Pass                 1.000000 -0.999566
# Fail                -0.999566  1.000000

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=medium_districts_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts with 30-60K students')

# %% [markdown]
# ### We continue to see the negative correlation to Revenue per student on this size districts - 30-60K students.
#
# ### We see also that the difference in mean scale scores reduces between ethnicities for these districts, which in the larger districts we saw a larger difference between them on results.

# %% [markdown]
# # Small Districts Analysis

# %%
_ = plt.hist(small_districts_df['Revenue per student'], density=False, bins=30)
_ = plt.ylabel('Number of ocurrences')
_ = plt.xlabel('Revenue')
_ = plt.title("Revenue per Student - Districts with 10-30K students")

# %%
a, b = best_fit(small_districts_df['Revenue per student'],small_districts_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(small_districts_df['Revenue per student'],small_districts_df['Mean Scale Score'])
yfit = [a + b * xi for xi in small_districts_df['Revenue per student']]
plt.plot(small_districts_df['Revenue per student'], yfit)
plt.title('Mean Scale Score relationship to Revenue for 10-30K Students')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2580.53 + -0.01x

# %%
small_corr_df= small_districts_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
small_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.107278          0.041239
# Revenue per student          0.107278             1.000000         -0.217778
# Mean Scale Score             0.041239            -0.217778          1.000000
# Pass                         0.015490            -0.209286          0.832702
# Fail                        -0.016953             0.210295         -0.833202
#
#                          Pass      Fail
# Total Enrollment     0.015490 -0.016953
# Revenue per student -0.209286  0.210295
# Mean Scale Score     0.832702 -0.833202
# Pass                 1.000000 -0.999549
# Fail                -0.999549  1.000000

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=small_districts_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts with 10-30K students')

# %% [markdown]
# ### The downward slope and negative correlation continue to appear on these size districts 10-30 K students. Looking at the mean scores and the difference between ethnicities, we want to evaluate the enrollment size against mean scores and studdents passing, which seems the larger the group the lower the scores.

# %%
a, b = best_fit(small_districts_df['Total Enrollment'],small_districts_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(small_districts_df['Total Enrollment'],small_districts_df['Mean Scale Score'])
yfit = [a + b * xi for xi in small_districts_df['Revenue per student']]
plt.plot(small_districts_df['Total Enrollment'], yfit)
plt.title('Mean Scale Score relationship to Enrollment for 10-30K Students')
plt.xlabel('Total Enrollment')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2517.06 + 0.00x

# %%
asian_df = df[df['Subgroup ID']=='Asian or Asian/Pacific Islander']
black_df = df[df['Subgroup ID']=='Black']
amerindian_df = df[df['Subgroup ID']=='American Indian/Alaska Native']
hawaiian_df = df[df['Subgroup ID']=='Hawaiian Native/Pacific Islander']
two_df = df[df['Subgroup ID']=='Black']
hispanic_df = df[df['Subgroup ID']=='Hispanic']
white_df = df[df['Subgroup ID']=='White']

# %%
#Scatter plot for each ethnicity.
md_asian_df = medium_districts_df[medium_districts_df['Subgroup ID']=='Asian or Asian/Pacific Islander']
md_black_df = medium_districts_df[medium_districts_df['Subgroup ID']=='Black']
md_amerindian_df = medium_districts_df[medium_districts_df['Subgroup ID']=='American Indian/Alaska Native']
md_hawaiian_df = medium_districts_df[medium_districts_df['Subgroup ID']=='Hawaiian Nat./Pacific Isl.']
md_two_df = medium_districts_df[medium_districts_df['Subgroup ID']=='Black']
md_hispanic_df = medium_districts_df[medium_districts_df['Subgroup ID']=='Hispanic']
md_white_df = medium_districts_df[medium_districts_df['Subgroup ID']=='White']
sd_asian_df = small_districts_df[small_districts_df['Subgroup ID']=='Asian or Asian/Pacific Islander']
sd_black_df = small_districts_df[small_districts_df['Subgroup ID']=='Black']
sd_amerindian_df = small_districts_df[small_districts_df['Subgroup ID']=='American Indian/Alaska Native']
sd_hawaiian_df = small_districts_df[small_districts_df['Subgroup ID']=='Hawaiian Nat./Pacific Isl.']
sd_two_df = small_districts_df[small_districts_df['Subgroup ID']=='Black']
sd_hispanic_df = small_districts_df[small_districts_df['Subgroup ID']=='Hispanic']
sd_white_df = small_districts_df[small_districts_df['Subgroup ID']=='White']

# %%
asian_corr_df= asian_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
asian_corr_df.corr()
# Out:
#                                 Total Enrollment  Revenue per student  \
# Total Enrollment                        1.000000             0.135718
# Revenue per student                     0.135718             1.000000
# Count Enrollment per ethnicity          0.667978            -0.049370
# Mean Scale Score                       -0.021562            -0.303986
# Pass                                   -0.020892            -0.337045
# Fail                                    0.021974             0.336540
#
#                                 Count Enrollment per ethnicity  \
# Total Enrollment                                      0.667978
# Revenue per student                                  -0.049370
# Count Enrollment per ethnicity                        1.000000
# Mean Scale Score                                      0.042653
# Pass                                                  0.085488
# Fail                                                 -0.083616
#
#                                 Mean Scale Score      Pass      Fail
# Total Enrollment                       -0.021562 -0.020892  0.021974
# Revenue per student                    -0.303986 -0.337045  0.336540
# Count Enrollment per ethnicity          0.042653  0.085488 -0.083616
# Mean Scale Score                        1.000000  0.737157 -0.736959
# Pass                                    0.737157  1.000000 -0.999327
# Fail                                   -0.736959 -0.999327  1.000000

# %%
#We see a positive correllation on the enrollment per ethnicity on the specific ethnicity
a, b = best_fit(md_asian_df['Count Enrollment per ethnicity'],md_asian_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(md_asian_df['Count Enrollment per ethnicity'],md_asian_df['Mean Scale Score'])
yfit = [a + b * xi for xi in md_asian_df['Count Enrollment per ethnicity']]
plt.plot(md_asian_df['Count Enrollment per ethnicity'], yfit)
plt.title('Mean Scale Score relationship to Enrollment of Asian Students')
plt.xlabel('Enrollment')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2551.36 + 0.00x

# %%
#We see a positive correllation on the enrollment per ethnicity on the specific ethnicity
a, b = best_fit(md_white_df['Count Enrollment per ethnicity'],md_white_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(md_white_df['Count Enrollment per ethnicity'],md_white_df['Mean Scale Score'])
yfit = [a + b * xi for xi in md_white_df['Count Enrollment per ethnicity']]
plt.plot(md_white_df['Count Enrollment per ethnicity'], yfit)
plt.title('Mean Scale Score relationship to Enrollment of Asian Students')
plt.xlabel('Enrollment')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2520.94 + 0.00x

# %%
black_corr_df= black_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
black_corr_df.corr()
# Out:
#                                 Total Enrollment  Revenue per student  \
# Total Enrollment                        1.000000             0.071473
# Revenue per student                     0.071473             1.000000
# Count Enrollment per ethnicity          0.947729             0.157857
# Mean Scale Score                       -0.018937            -0.211272
# Pass                                    0.000366            -0.230491
# Fail                                    0.002666             0.230552
#
#                                 Count Enrollment per ethnicity  \
# Total Enrollment                                      0.947729
# Revenue per student                                   0.157857
# Count Enrollment per ethnicity                        1.000000
# Mean Scale Score                                     -0.110272
# Pass                                                 -0.074372
# Fail                                                  0.077566
#
#                                 Mean Scale Score      Pass      Fail
# Total Enrollment                       -0.018937  0.000366  0.002666
# Revenue per student                    -0.211272 -0.230491  0.230552
# Count Enrollment per ethnicity         -0.110272 -0.074372  0.077566
# Mean Scale Score                        1.000000  0.766463 -0.769409
# Pass                                    0.766463  1.000000 -0.999073
# Fail                                   -0.769409 -0.999073  1.000000

# %%
a, b = best_fit(md_black_df['Count Enrollment per ethnicity'],md_black_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(md_black_df['Count Enrollment per ethnicity'],md_black_df['Mean Scale Score'])
yfit = [a + b * xi for xi in md_black_df['Count Enrollment per ethnicity']]
plt.plot(md_black_df['Count Enrollment per ethnicity'], yfit)
plt.title('Mean Scale Score relationship to Enrollment for Black Students')
plt.xlabel('Enrollment')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2507.79 + -0.01x

# %%
a, b = best_fit(md_hispanic_df['Count Enrollment per ethnicity'],md_hispanic_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(md_hispanic_df['Count Enrollment per ethnicity'],md_hispanic_df['Mean Scale Score'])
yfit = [a + b * xi for xi in md_hispanic_df['Count Enrollment per ethnicity']]
plt.plot(md_hispanic_df['Count Enrollment per ethnicity'], yfit)
plt.title('Mean Scale Score relationship to Enrollment for hispanic Students')
plt.xlabel('Enrollment')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2504.56 + -0.00x

# %% [markdown]
# ### We can see how on smaller enrollment the scores seem to increase. For black and hispanic students.

# %% [markdown]
# # Smaller Districts Analysis

# %%
_ = plt.hist(smaller_districts_df['Revenue per student'], density=False, bins=30)
_ = plt.ylabel('Number of ocurrences')
_ = plt.xlabel('Revenue')
_ = plt.title("Revenue per Student - Districts with less than 10k students")

# %%
#Which is the ethnicity precence on each of these schools
plt.figure(figsize=(10, 4))
sns.barplot(x='Count Enrollment per ethnicity',y='Agency Name',hue='Subgroup ID',data=smaller_districts_df)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
smaller_corr_df= smaller_districts_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'Count Enrollment per ethnicity',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
smaller_corr_df.corr()
# Out:
#                      Total Enrollment  Revenue per student  Mean Scale Score  \
# Total Enrollment             1.000000             0.014934          0.050273
# Revenue per student          0.014934             1.000000         -0.252285
# Mean Scale Score             0.050273            -0.252285          1.000000
# Pass                        -0.011607            -0.238339          0.801617
# Fail                         0.008001             0.239932         -0.803947
#
#                          Pass      Fail
# Total Enrollment    -0.011607  0.008001
# Revenue per student -0.238339  0.239932
# Mean Scale Score     0.801617 -0.803947
# Pass                 1.000000 -0.999377
# Fail                -0.999377  1.000000

# %%
a, b = best_fit(smaller_districts_df['Revenue per student'],smaller_districts_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(smaller_districts_df['Revenue per student'],smaller_districts_df['Mean Scale Score'])
yfit = [a + b * xi for xi in smaller_districts_df['Revenue per student']]
plt.plot(smaller_districts_df['Revenue per student'], yfit)
plt.title('Mean Scale Score relationship to Revenue for Districts with less than 10K Students')
plt.xlabel('Revenue per Student')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2581.07 + -0.01x

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=smaller_districts_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts with les 10K students')

# %%
a, b = best_fit(sd_hispanic_df['Count Enrollment per ethnicity'],sd_hispanic_df['Mean Scale Score'])
import matplotlib.pyplot as plt
plt.scatter(sd_hispanic_df['Count Enrollment per ethnicity'],sd_hispanic_df['Mean Scale Score'])
yfit = [a + b * xi for xi in sd_hispanic_df['Count Enrollment per ethnicity']]
plt.plot(sd_hispanic_df['Count Enrollment per ethnicity'], yfit)
plt.title('Mean Scale Score relationship to Enrollment for Hispanic Students on Districts with less than 10k Students')
plt.xlabel('Enrollment')
_=plt.ylabel('Mean Scale Score')
# Out:
# best fit line:
# y = 2511.05 + -0.00x

# %%
srd_black_df = smaller_districts_df[smaller_districts_df['Subgroup ID']=='Black']
black_srd_corr_df= srd_black_df.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
black_srd_corr_df.corr()
# Out:
#                                 Total Enrollment  Revenue per student  \
# Total Enrollment                        1.000000            -0.181758
# Revenue per student                    -0.181758             1.000000
# Count Enrollment per ethnicity          0.251115             0.311665
# Mean Scale Score                        0.012138            -0.217438
# Pass                                    0.030028            -0.196387
# Fail                                   -0.034887             0.200304
#
#                                 Count Enrollment per ethnicity  \
# Total Enrollment                                      0.251115
# Revenue per student                                   0.311665
# Count Enrollment per ethnicity                        1.000000
# Mean Scale Score                                     -0.140371
# Pass                                                 -0.157504
# Fail                                                  0.157925
#
#                                 Mean Scale Score      Pass      Fail
# Total Enrollment                        0.012138  0.030028 -0.034887
# Revenue per student                    -0.217438 -0.196387  0.200304
# Count Enrollment per ethnicity         -0.140371 -0.157504  0.157925
# Mean Scale Score                        1.000000  0.740847 -0.744543
# Pass                                    0.740847  1.000000 -0.998653
# Fail                                   -0.744543 -0.998653  1.000000

# %% [markdown]
# ## Tiny districts: between 1,000 and 5,000 total enrollment

# %%
tiny_districts =df[(df['Total Enrollment'] < 5_000) & (df['Total Enrollment'] >= 1000)]
tiny_districts.head(5)
# Out:
#        District Code          Agency Name  Total Enrollment  Total Revenue  \
# 4441         61127.0  ALBANY CITY UNIFIED            3702.0     58211000.0
# 4442         61127.0  ALBANY CITY UNIFIED            3702.0     58211000.0
# 4443         61127.0  ALBANY CITY UNIFIED            3702.0     58211000.0
# 4440         61127.0  ALBANY CITY UNIFIED            3702.0     58211000.0
# 11113        61127.0  ALBANY CITY UNIFIED            3702.0     58211000.0
#
#        Revenue per student        Subgroup ID  Count Enrollment per ethnicity  \
# 4441               15724.2              White                          1368.0
# 4442               15724.2              White                          1368.0
# 4443               15724.2              White                          1368.0
# 4440               15724.2              White                          1368.0
# 11113              15724.2  Two or More Races                           522.0
#
#        County Code  Test Id  Mean Scale Score  ...   \
# 4441           1.0      2.0       2603.300000  ...
# 4442           1.0      2.0       2576.400000  ...
# 4443           1.0      1.0       2588.200000  ...
# 4440           1.0      1.0       2601.885714  ...
# 11113          1.0      2.0       2588.185714  ...
#
#        Total Standard Nearly Met  Total Standard Not Met      Disadvantaged  \
# 4441                        88.0                    41.0  Not Disadvantaged
# 4442                         1.0                     4.0      Disadvantaged
# 4443                         2.0                     2.0      Disadvantaged
# 4440                        69.0                    32.0  Not Disadvantaged
# 11113                       39.0                    27.0  Not Disadvantaged
#
#        Percentate Std Exceed  Percentage Std Met  Percentage Std Nearly Met  \
# 4441                    53.0                28.0                       13.0
# 4442                    38.0                23.0                        8.0
# 4443                     8.0                62.0                       15.0
# 4440                    54.0                31.0                       10.0
# 11113                   50.0                23.0                       16.0
#
#        Percentage Std Not Met  Percentage Std Met and Above  Pass  Fail
# 4441                      6.0                          81.0  81.0  19.0
# 4442                     31.0                          62.0  61.0  39.0
# 4443                     15.0                          69.0  70.0  30.0
# 4440                      5.0                          85.0  85.0  15.0
# 11113                    11.0                          73.0  73.0  27.0
#
# [5 rows x 28 columns]

# %%
# correlation between the variables
corr= tiny_districts.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
corr=corr.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col0 {
#             background-color:  #b40426;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col1 {
#             background-color:  #7ea1fa;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col2 {
#             background-color:  #bcd2f7;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col3 {
#             background-color:  #dbdcde;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col4 {
#             background-color:  #ebd3c6;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col5 {
#             background-color:  #ccd9ed;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col0 {
#             background-color:  #5b7ae5;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col1 {
#             background-color:  #b40426;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col2 {
#             background-color:  #7da0f9;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col3 {
#             background-color:  #a5c3fe;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col4 {
#             background-color:  #b6cefa;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col5 {
#             background-color:  #f5c2aa;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col0 {
#             background-color:  #c1d4f4;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col1 {
#             background-color:  #a2c1ff;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col2 {
#             background-color:  #b40426;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col3 {
#             background-color:  #c3d5f4;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col4 {
#             background-color:  #d1dae9;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col5 {
#             background-color:  #e9d5cb;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col0 {
#             background-color:  #7396f5;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col1 {
#             background-color:  #4055c8;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col2 {
#             background-color:  #3d50c3;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col3 {
#             background-color:  #b40426;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col4 {
#             background-color:  #d44e41;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col5 {
#             background-color:  #5572df;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col0 {
#             background-color:  #80a3fa;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col3 {
#             background-color:  #d65244;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col4 {
#             background-color:  #b40426;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row5_col1 {
#             background-color:  #c6d6f1;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row5_col2 {
#             background-color:  #7093f3;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row5_col3 {
#             background-color:  #3b4cc0;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row5_col4 {
#             background-color:  #3b4cc0;
#         }    #T_0cf154b8_58eb_11eb_a858_0242ac110002row5_col5 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_0cf154b8_58eb_11eb_a858_0242ac110002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total Enrollment</th>
#         <th class="col_heading level0 col1" >Revenue per student</th>
#         <th class="col_heading level0 col2" >Count Enrollment per ethnicity</th>
#         <th class="col_heading level0 col3" >Mean Scale Score</th>
#         <th class="col_heading level0 col4" >Pass</th>
#         <th class="col_heading level0 col5" >Fail</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0cf154b8_58eb_11eb_a858_0242ac110002level0_row0" class="row_heading level0 row0" >Total Enrollment</th>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col0" class="data row0 col0" >1</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col1" class="data row0 col1" >0.00148018</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col2" class="data row0 col2" >0.332668</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col3" class="data row0 col3" >0.0811932</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col4" class="data row0 col4" >0.118741</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row0_col5" class="data row0 col5" >-0.117428</td>
#     </tr>    <tr>
#         <th id="T_0cf154b8_58eb_11eb_a858_0242ac110002level0_row1" class="row_heading level0 row1" >Revenue per student</th>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col0" class="data row1 col0" >0.00148018</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col1" class="data row1 col1" >1</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col2" class="data row1 col2" >0.129754</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col3" class="data row1 col3" >-0.238121</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col4" class="data row1 col4" >-0.265127</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row1_col5" class="data row1 col5" >0.264933</td>
#     </tr>    <tr>
#         <th id="T_0cf154b8_58eb_11eb_a858_0242ac110002level0_row2" class="row_heading level0 row2" >Count Enrollment per ethnicity</th>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col0" class="data row2 col0" >0.332668</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col1" class="data row2 col1" >0.129754</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col2" class="data row2 col2" >1</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col3" class="data row2 col3" >-0.0800059</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col4" class="data row2 col4" >-0.0925791</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row2_col5" class="data row2 col5" >0.0940096</td>
#     </tr>    <tr>
#         <th id="T_0cf154b8_58eb_11eb_a858_0242ac110002level0_row3" class="row_heading level0 row3" >Mean Scale Score</th>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col0" class="data row3 col0" >0.0811932</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col1" class="data row3 col1" >-0.238121</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col2" class="data row3 col2" >-0.0800059</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col3" class="data row3 col3" >1</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col4" class="data row3 col4" >0.819772</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row3_col5" class="data row3 col5" >-0.820068</td>
#     </tr>    <tr>
#         <th id="T_0cf154b8_58eb_11eb_a858_0242ac110002level0_row4" class="row_heading level0 row4" >Pass</th>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col0" class="data row4 col0" >0.118741</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col1" class="data row4 col1" >-0.265127</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col2" class="data row4 col2" >-0.0925791</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col3" class="data row4 col3" >0.819772</td>
#         <td id="T_0cf154b8_58eb_11eb_a858_0242ac110002row4_col4" clas

# %%
_ = plt.hist(tiny_districts_ID1['Revenue per student'], density=False, bins=30)
_ = plt.ylabel('Number of ocurrences')
_ = plt.xlabel('Revenue')
_ = plt.title("Revenue per Student")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-65c31a136fe4> in <module>
# ----> 1 _ = plt.hist(tiny_districts_ID1['Revenue per student'], density=False, bins=30)
#       2 _ = plt.ylabel('Number of ocurrences')
#       3 _ = plt.xlabel('Revenue')
#       4 _ = plt.title("Revenue per Student")
#
# NameError: name 'tiny_districts_ID1' is not defined

# %%
scatterplot1 = tiny_districts[['Revenue per student', 'Mean Scale Score']]
scatterplot1
scatterplot1.plot.scatter(x='Revenue per student', y='Mean Scale Score')

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=tiny_districts)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts with les 10K students')

# %%
#_ = sns.catplot(x='Mean Scale Score', y="Revenue per student", hue="Subgroup ID", kind="swarm", data=tiny_districts_ID1)

# %% [markdown]
# ## Mini districts: total enrollment less than 1,000

# %%
mini_districts = df[(df['Total Enrollment'] < 1000)]
print(mini_districts.shape)

mini_districts.head(5)
# Out:
# (728, 28)
#       District Code    Agency Name  Total Enrollment  Total Revenue  \
# 1816        61408.0  BIGGS UNIFIED             617.0      6067000.0
# 1817        61408.0  BIGGS UNIFIED             617.0      6067000.0
# 4630        61408.0  BIGGS UNIFIED             617.0      6067000.0
# 4631        61408.0  BIGGS UNIFIED             617.0      6067000.0
# 4632        61408.0  BIGGS UNIFIED             617.0      6067000.0
#
#       Revenue per student Subgroup ID  Count Enrollment per ethnicity  \
# 1816              9833.06    Hispanic                           231.0
# 1817              9833.06    Hispanic                           231.0
# 4630              9833.06       White                           348.0
# 4631              9833.06       White                           348.0
# 4632              9833.06       White                           348.0
#
#       County Code  Test Id  Mean Scale Score  ...   Total Standard Nearly Met  \
# 1816          4.0      2.0       2456.400000  ...                        26.0
# 1817          4.0      1.0       2442.516667  ...                        32.0
# 4630          4.0      1.0       2428.580000  ...                        13.0
# 4631          4.0      2.0       2418.950000  ...                         9.0
# 4632          4.0      2.0       2503.400000  ...                        10.0
#
#       Total Standard Not Met      Disadvantaged  Percentate Std Exceed  \
# 1816                    53.0      Disadvantaged                    0.0
# 1817                    50.0      Disadvantaged                    4.0
# 4630                    32.0      Disadvantaged                   10.0
# 4631                    32.0      Disadvantaged                    4.0
# 4632                    16.0  Not Disadvantaged                    0.0
#
#       Percentage Std Met  Percentage Std Nearly Met  Percentage Std Not Met  \
# 1816                10.0                       30.0                    60.0
# 1817                12.0                       33.0                    51.0
# 4630                19.0                       21.0                    51.0
# 4631                20.0                       17.0                    59.0
# 4632                19.0                       31.0                    50.0
#
#       Percentage Std Met and Above  Pass  Fail
# 1816                          10.0  10.0  90.0
# 1817                          16.0  16.0  84.0
# 4630                          29.0  29.0  72.0
# 4631                          24.0  24.0  76.0
# 4632                          19.0  19.0  81.0
#
# [5 rows x 28 columns]

# %%
# correlation between the variables
corr1tiny = tiny_districts.drop(columns=['District Code', 'Agency Name', 'Total Revenue',
       'County Code', 'Test Id',
       'Total Tested At Entity Level', 'Total Tested with Scores',
       'CAASPP Reported Enrollment', 'Students Tested', 'Students with Scores',
       'Total Standard Exceeded', 'Total Standard Met',
       'Total Standard Met and Above', 'Total Standard Nearly Met',
       'Total Standard Not Met', 'Percentate Std Exceed', 'Percentage Std Met',
       'Percentage Std Nearly Met', 'Percentage Std Not Met',
       'Percentage Std Met and Above'])
corr1tiny=corr1tiny.corr()
corr1tiny.style.background_gradient(cmap='coolwarm')
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_106af77a_58eb_11eb_a858_0242ac110002row0_col0 {
#             background-color:  #b40426;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row0_col1 {
#             background-color:  #7ea1fa;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row0_col2 {
#             background-color:  #bcd2f7;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row0_col3 {
#             background-color:  #dbdcde;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row0_col4 {
#             background-color:  #ebd3c6;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row0_col5 {
#             background-color:  #ccd9ed;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row1_col0 {
#             background-color:  #5b7ae5;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row1_col1 {
#             background-color:  #b40426;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row1_col2 {
#             background-color:  #7da0f9;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row1_col3 {
#             background-color:  #a5c3fe;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row1_col4 {
#             background-color:  #b6cefa;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row1_col5 {
#             background-color:  #f5c2aa;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row2_col0 {
#             background-color:  #c1d4f4;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row2_col1 {
#             background-color:  #a2c1ff;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row2_col2 {
#             background-color:  #b40426;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row2_col3 {
#             background-color:  #c3d5f4;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row2_col4 {
#             background-color:  #d1dae9;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row2_col5 {
#             background-color:  #e9d5cb;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row3_col0 {
#             background-color:  #7396f5;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row3_col1 {
#             background-color:  #4055c8;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row3_col2 {
#             background-color:  #3d50c3;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row3_col3 {
#             background-color:  #b40426;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row3_col4 {
#             background-color:  #d44e41;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row3_col5 {
#             background-color:  #5572df;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row4_col0 {
#             background-color:  #80a3fa;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row4_col3 {
#             background-color:  #d65244;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row4_col4 {
#             background-color:  #b40426;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row5_col1 {
#             background-color:  #c6d6f1;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row5_col2 {
#             background-color:  #7093f3;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row5_col3 {
#             background-color:  #3b4cc0;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row5_col4 {
#             background-color:  #3b4cc0;
#         }    #T_106af77a_58eb_11eb_a858_0242ac110002row5_col5 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_106af77a_58eb_11eb_a858_0242ac110002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total Enrollment</th>
#         <th class="col_heading level0 col1" >Revenue per student</th>
#         <th class="col_heading level0 col2" >Count Enrollment per ethnicity</th>
#         <th class="col_heading level0 col3" >Mean Scale Score</th>
#         <th class="col_heading level0 col4" >Pass</th>
#         <th class="col_heading level0 col5" >Fail</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_106af77a_58eb_11eb_a858_0242ac110002level0_row0" class="row_heading level0 row0" >Total Enrollment</th>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row0_col0" class="data row0 col0" >1</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row0_col1" class="data row0 col1" >0.00148018</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row0_col2" class="data row0 col2" >0.332668</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row0_col3" class="data row0 col3" >0.0811932</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row0_col4" class="data row0 col4" >0.118741</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row0_col5" class="data row0 col5" >-0.117428</td>
#     </tr>    <tr>
#         <th id="T_106af77a_58eb_11eb_a858_0242ac110002level0_row1" class="row_heading level0 row1" >Revenue per student</th>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row1_col0" class="data row1 col0" >0.00148018</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row1_col1" class="data row1 col1" >1</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row1_col2" class="data row1 col2" >0.129754</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row1_col3" class="data row1 col3" >-0.238121</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row1_col4" class="data row1 col4" >-0.265127</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row1_col5" class="data row1 col5" >0.264933</td>
#     </tr>    <tr>
#         <th id="T_106af77a_58eb_11eb_a858_0242ac110002level0_row2" class="row_heading level0 row2" >Count Enrollment per ethnicity</th>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row2_col0" class="data row2 col0" >0.332668</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row2_col1" class="data row2 col1" >0.129754</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row2_col2" class="data row2 col2" >1</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row2_col3" class="data row2 col3" >-0.0800059</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row2_col4" class="data row2 col4" >-0.0925791</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row2_col5" class="data row2 col5" >0.0940096</td>
#     </tr>    <tr>
#         <th id="T_106af77a_58eb_11eb_a858_0242ac110002level0_row3" class="row_heading level0 row3" >Mean Scale Score</th>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row3_col0" class="data row3 col0" >0.0811932</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row3_col1" class="data row3 col1" >-0.238121</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row3_col2" class="data row3 col2" >-0.0800059</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row3_col3" class="data row3 col3" >1</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row3_col4" class="data row3 col4" >0.819772</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row3_col5" class="data row3 col5" >-0.820068</td>
#     </tr>    <tr>
#         <th id="T_106af77a_58eb_11eb_a858_0242ac110002level0_row4" class="row_heading level0 row4" >Pass</th>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row4_col0" class="data row4 col0" >0.118741</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row4_col1" class="data row4 col1" >-0.265127</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row4_col2" class="data row4 col2" >-0.0925791</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row4_col3" class="data row4 col3" >0.819772</td>
#         <td id="T_106af77a_58eb_11eb_a858_0242ac110002row4_col4" clas

# %%
_ = plt.hist(mini_districts['Revenue per student'], density=False, bins=30)
_ = plt.ylabel('Number of ocurrences')
_ = plt.xlabel('Revenue')
_ = plt.title("Revenue per Student")

# %%
scatterplot1 = mini_districts[['Revenue per student', 'Mean Scale Score']]
scatterplot1
scatterplot1.plot.scatter(x='Revenue per student', y='Mean Scale Score')

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=mini_districts)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts with les 10K students')

# %% [markdown]
# # When we see the distribution of revenue regardless of the size of the districts, we see a range of 4K to 14K in revenue per student.
#
# # Will create a dataset with all districts on the lower revenue per student to see what is the size of those schools which seem to get the higher scores. See if we can find a pattern there.

# %%
low_revenue_df = df[df['Revenue per student'] <= 8000]
median_revenue_df=df[(df['Revenue per student'] > 8000) & (df['Revenue per student'] <= 12000)]

# %%
low_revenue_df['Total Enrollment'].describe()
# Out:
# count      2166.000000
# mean      10477.005078
# std       17208.167773
# min         254.000000
# 25%        2432.000000
# 50%        5125.000000
# 75%       10659.000000
# max      128040.000000
# Name: Total Enrollment, dtype: float64

# %%
low_revenue_df['Mean Scale Score'].describe()
# Out:
# count    2166.000000
# mean     2539.912026
# std        62.744936
# min      2366.600000
# 25%      2494.150000
# 50%      2536.700000
# 75%      2579.433333
# max      2775.200000
# Name: Mean Scale Score, dtype: float64

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=low_revenue_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts with les 8K dollars per Student')

# %%
#An all district groups we see the median or majority of the districts fall within this category
median_revenue_df['Total Enrollment'].describe()
# Out:
# count     4357.000000
# mean     12901.822125
# std      13361.732543
# min        251.000000
# 25%       3219.000000
# 50%       9302.000000
# 75%      17326.000000
# max      76428.000000
# Name: Total Enrollment, dtype: float64

# %%
median_revenue_df['Revenue per student'].describe()
# Out:
# count     4357.000000
# mean      9931.310675
# std       1099.711102
# min       8015.050000
# 25%       9024.950000
# 50%       9844.340000
# 75%      10752.940000
# max      11999.510000
# Name: Revenue per student, dtype: float64

# %%
sns.catplot(x="Subgroup ID", y="Mean Scale Score", hue="Test Id", kind="box", data=median_revenue_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Mean Scale Score boxplots for Districts between 8k to 12k dollars per Student')

# %%
sns.catplot(x="Subgroup ID", y="Pass", kind="box", data=median_revenue_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Percent of Students pass boxplots for Districts between 8k to 12k dollars per Student')

# %%
sns.catplot(x="Subgroup ID", y="Count Enrollment per ethnicity",kind="box", data=median_revenue_df)
plt.xticks(rotation=45, ha='right')
_=plt.title('Enrollment per ethnicity boxplots for Districts between 8k to 12k dollars per Student')

# %% [markdown]
# ---------------

# %% [markdown]
# ## Conclusions (as of now):
# 1. The correlation between revenue per student and students' outcome is a negative correlation regardless of the size in the district or the ethnic group.
# 2. There is also a negative correlation to District size with significative changes in the students's outcome, which show that black and hispanic students perform better on smaller Districts and have less differences with Asian and White Students.
#
#
# ## Observations:
# 1. We don't have the data overtime. It'll be hard to come to a conclusion if revenue is affecting test scores if we don't know what the test scores and revenue have been in the past.
# 2. Our conclusions will be based on the year we have the data for.
#
# ## NEXT STEPS:
# 1. How is the revenue used on schools with higher revenue? at this moment we don't have that data.
# 2. Where is the additional revenue coming from for the higher revenue schools.
# 3. Are there special programs that provide those resources? Lit2, Sports, etc. Are teachers paid more on those districts.
# 2. Merge poverty dataset from Census?
# 3. Come up with more questions to investigate?
