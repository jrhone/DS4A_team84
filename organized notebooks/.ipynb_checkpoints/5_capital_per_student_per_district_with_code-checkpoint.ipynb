# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Data Wrangling
#
# ### The process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics.

# %% [markdown]
# ## The goal here is:
#
# - To join two data files, one containing total enrollment of students according to race per school district and one containing total revenue per school district.
# - Add a district code key from a text file containing school district name, school district code, and zipcode. The district code here will serve as a key to connect with another dataset containing students outcome.
#
# The final dataset should contain the following columns: Agency name, district code, zipcode, seven colmns representing total enrollment according to race, total enrollment, total revenue and a new column containing revenue per student for each school district.

# %% [markdown]
# ### Reading files:
# 1. Total enrollment according to race per school dsitrict:

# %%
df_enrollment = pd.read_csv('district_code/total_enrollment_per_race.csv', index_col=0)
df_enrollment.head()
# Out:
#                 Agency Name   Black  Hispanic   White  \
# 0               ABC UNIFIED  1791.0    9425.0  1302.0
# 1       ACALANES UNION HIGH    95.0     508.0  3622.0
# 2          ACKERMAN CHARTER     4.0      74.0   460.0
# 3  ACTON-AGUA DULCE UNIFIED   705.0    3466.0  4199.0
# 4       ADELANTO ELEMENTARY  2156.0    6327.0  1010.0
#
#    Asian or Pacific Islander  American Indian/Alaska Native  \
# 0                     7459.0                           63.0
# 1                      850.0                            9.0
# 2                        9.0                            2.0
# 3                      536.0                           36.0
# 4                      139.0                           35.0
#
#    Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment
# 0                             158.0              524.0           20722.0
# 1                              16.0              402.0            5502.0
# 2                               0.0               37.0             586.0
# 3                              18.0             1040.0           10000.0
# 4                              88.0              517.0           10272.0

# %% [markdown]
# 2. Total revenue per school district:

# %%
df_revenue = pd.read_csv('district_code/total_revenue_per_district.csv', index_col=0)
df_revenue.head()
# Out:
#                 Agency Name  Total Local Revenue  Total State Revenue  \
# 0               ABC UNIFIED          171312000.0           39046000.0
# 1       ACALANES UNION HIGH           27481000.0            8624000.0
# 2          ACKERMAN CHARTER            3714000.0             473000.0
# 3  ACTON-AGUA DULCE UNIFIED           25820000.0            2913000.0
# 4       ADELANTO ELEMENTARY           96654000.0           12463000.0
#
#    Total Federal Revenue  Total Revenue
# 0             15893000.0    226251000.0
# 1              1605000.0     37710000.0
# 2               223000.0      4410000.0
# 3              1250000.0     29983000.0
# 4             10906000.0    120023000.0

# %% [markdown]
# 3. Text file containing district code, district name, and zipcode:

# %%
df_distcode = pd.read_csv('district_code/districCode_ca2017entities_csv.txt')
df_distcode.head()
# Out:
#    County Code  District Code  School Code  Filler  Test Year  Type Id  \
# 0            0              0            0     NaN       2017        4
# 1            1              0            0     NaN       2017        5
# 2            1          10017            0     NaN       2017        6
# 3            1          10017       112607     NaN       2017        9
# 4            1          10017       123968     NaN       2017        9
#
#            County Name                            District Name  \
# 0  State of California                                      NaN
# 1              Alameda                                      NaN
# 2              Alameda       Alameda County Office Of Education
# 3              Alameda   Envision Academy For Arts & Technology
# 4              Alameda  Community School For Creative Education
#
#                                School Name Zip Code
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3   Envision Academy For Arts & Technology    94612
# 4  Community School For Creative Education    94606

# %% [markdown]
# ### Joining enrollment dataset + total revenue per district:

# %%
# filtering only the last column of the revenue dataset

df_total_revenue = df_revenue.drop(df_revenue.columns[0:-1], axis = 1)
#df_total_revenue.head()

# %%
df_enrollment_revenue = pd.merge(df_enrollment, df_total_revenue, left_index=True, right_index=True)
df_enrollment_revenue.head()
# Out:
#                 Agency Name   Black  Hispanic   White  \
# 0               ABC UNIFIED  1791.0    9425.0  1302.0
# 1       ACALANES UNION HIGH    95.0     508.0  3622.0
# 2          ACKERMAN CHARTER     4.0      74.0   460.0
# 3  ACTON-AGUA DULCE UNIFIED   705.0    3466.0  4199.0
# 4       ADELANTO ELEMENTARY  2156.0    6327.0  1010.0
#
#    Asian or Pacific Islander  American Indian/Alaska Native  \
# 0                     7459.0                           63.0
# 1                      850.0                            9.0
# 2                        9.0                            2.0
# 3                      536.0                           36.0
# 4                      139.0                           35.0
#
#    Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 0                             158.0              524.0           20722.0
# 1                              16.0              402.0            5502.0
# 2                               0.0               37.0             586.0
# 3                              18.0             1040.0           10000.0
# 4                              88.0              517.0           10272.0
#
#    Total Revenue
# 0    226251000.0
# 1     37710000.0
# 2      4410000.0
# 3     29983000.0
# 4    120023000.0

# %% [markdown]
# ### Adding the column 'Revenue per student':

# %%
df_enrollment_revenue['Revenue per student'] = df_enrollment_revenue['Total Revenue']/df_enrollment_revenue['Total Enrollment']
df_enrollment_revenue['Revenue per student'] = round(df_enrollment_revenue['Revenue per student'], 2) 


df_enrollment_revenue.sort_values(by=['Agency Name'])
df_enrollment_revenue.head(35)
# Out:
#                                       Agency Name   Black  Hispanic   White  \
# 0                                     ABC UNIFIED  1791.0    9425.0  1302.0
# 1                             ACALANES UNION HIGH    95.0     508.0  3622.0
# 2                                ACKERMAN CHARTER     4.0      74.0   460.0
# 3                        ACTON-AGUA DULCE UNIFIED   705.0    3466.0  4199.0
# 4                             ADELANTO ELEMENTARY  2156.0    6327.0  1010.0
# 5            ALAMEDA CNTY. STUDENT EXCHANGE PROG.     0.0       0.0     0.0
# 6              ALAMEDA COUNTY OFFICE OF EDUCATION   543.0    1581.0   209.0
# 7                                 ALAMEDA UNIFIED   924.0    1897.0  3292.0
# 8                             ALBANY CITY UNIFIED   117.0     603.0  1368.0
# 9               ALEXANDER VALLEY UNION ELEMENTARY     1.0      48.0    80.0
# 10                               ALHAMBRA UNIFIED   112.0    7071.0   349.0
# 11                                   ALISAL UNION    34.0    8414.0   117.0
# 12                         ALLENSWORTH ELEMENTARY     1.0      77.0     0.0
# 13                                ALPAUGH UNIFIED    16.0     501.0   213.0
# 14              ALPINE COUNTY OFFICE OF EDUCATION     0.0       0.0     0.0
# 15                          ALPINE COUNTY UNIFIED     0.0       4.0    42.0
# 16                        ALPINE UNION ELEMENTARY    37.0     400.0  1111.0
# 17                           ALTA LOMA ELEMENTARY   381.0    2676.0  2281.0
# 18                          ALTA VISTA ELEMENTARY     0.0     449.0    76.0
# 19               ALTA-DUTCH FLAT UNION ELEMENTARY     0.0       6.0    91.0
# 20                     ALUM ROCK UNION ELEMENTARY   156.0    9154.0   194.0
# 21              ALVIEW-DAIRYLAND UNION ELEMENTARY     0.0     213.0   156.0
# 22                              ALVINA ELEMENTARY     0.0     154.0    24.0
# 23                                 ALVORD UNIFIED   720.0   15161.0  2034.0
# 24              AMADOR COUNTY OFFICE OF EDUCATION     0.0      51.0   143.0
# 25                              AMADOR COUNTY ROP     0.0       0.0     0.0
# 26                          AMADOR COUNTY UNIFIED    23.0     780.0  2652.0
# 27                             ANAHEIM ELEMENTARY   265.0   15961.0   873.0
# 28                             ANAHEIM UNION HIGH   716.0   20555.0  3135.0
# 29                            ANDERSON UNION HIGH    30.0     293.0  1274.0
# 30                        ANDERSON VALLEY UNIFIED     5.0     384.0   110.0
# 31                            ANTELOPE ELEMENTARY     9.0     187.0   568.0
# 32                            ANTELOPE VALLEY ROP     0.0       0.0     0.0
# 33  ANTELOPE VALLEY SCHOOLS TRANSPORTATION AGENCY     0.0       0.0     0.0
# 34                     ANTELOPE VALLEY UNION HIGH  4207.0   14647.0  3260.0
#
#     Asian or Pacific Islander  American Indian/Alaska Native  \
# 0                      7459.0                           63.0
# 1                       850.0                            9.0
# 2                         9.0                            2.0
# 3                       536.0                           36.0
# 4                       139.0                           35.0
# 5                         0.0                            0.0
# 6                       263.0                           16.0
# 7                      3722.0                           33.0
# 8                      1080.0                            5.0
# 9                         0.0                            0.0
# 10                     9084.0                           33.0
# 11                      131.0                            4.0
# 12                        0.0                            0.0
# 13                       15.0                            4.0
# 14                        0.0                            2.0
# 15                        0.0                           32.0
# 16                       35.0                           81.0
# 17                      501.0                           31.0
# 18                        5.0                            4.0
# 19                        1.0                            1.0
# 20                     1868.0                           21.0
# 21                       10.0                            1.0
# 22                        1.0                            2.0
# 23                      949.0                           40.0
# 24                        0.0                            9.0
# 25                        0.0                            0.0
# 26                       54.0                          101.0
# 27                     1046.0                           18.0
# 28                     5287.0                          145.0
# 29                       49.0                          104.0
# 30                        1.0                            4.0
# 31                       11.0                           16.0
# 32                        0.0                            0.0
# 33                        0.0                            0.0
# 34                      628.0                           77.0
#
#     Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 0                              158.0              524.0           20722.0
# 1                               16.0              402.0            5502.0
# 2                                0.0               37.0             586.0
# 3                               18.0             1040.0           10000.0
# 4                               88.0              517.0           10272.0
# 5                                0.0                0.0               0.0
# 6                               33.0              225.0            2870.0
# 7                               85.0             1206.0           11159.0
# 8                                7.0              522.0            3702.0
# 9                                0.0                1.0             130.0
# 10                              16.0              406.0           17071.0
# 11                              18.0              517.0            9235.0
# 12                               0.0                0.0              78.0
# 13                               0.0               44.0             793.0
# 14                               0.0                0.0               2.0
# 15                               0.0                2.0              80.0
# 16                               7.0               74.0            1745.0
# 17                              28.0               90.0            5988.0
# 18                              19.0                2.0             555.0
# 19                               0.0                5.0             104.0
# 20                              97.0              134.0           11624.0
# 21                               0.0                1.0             381.0
# 22                               1.0                0.0             182.0
# 23                              85.0              245.0           19234.0
# 24                               0.0               19.0             222.0
# 25                               0.0                0.0               0.0
# 26                               9.0              245.0            3864.0
# 27                              67.0              328.0           18558.0
# 28                             167.0              726.0           30731.0
# 29                              10.0               52.0            1812.0
# 30                               0.0                3.0             507.0
# 31                               1.0               24.0             816.0
# 32                               0.0                0.0               0.0
# 33                               0.0                0.0               0.0
# 34                              46.0             1030.0           23895.0
#
#     Total Revenue  Revenue per student
# 0     226251000.0             10918.40
# 1      37710000.0              6853.87
# 2       4410000.0              7525.60
# 3      29983000.0              2998.30
# 4     120023000.0             11684.48
# 5             0.0                  NaN
# 6      55795000.0             19440.77
# 7      96642000.0              8660.45
# 8      58211000.0             15724.20
# 9       1123000.0              8638.46
# 10    250138000.0             14652.80
# 11    109541000.0             11861.51
# 12      1105000.0             14166.67
# 13      5021000.0              6331.65
# 14      1447000.0            723500.00
# 15      1714000.0             21425.00
# 16     13433000.0              7697.99
# 17     55109000.0              9203.24
# 18      7103000.0             12798.20
# 19       794000.0              7634.62
# 20    113219000.0              9740.11
# 21      3352000.0              8797.90
# 22      1769000.0              9719.78
# 23    222608000.0             11573.67
# 24     12859000.0             57923.42
# 25            0.0                  NaN
# 26     17515000.0              4532.87
# 27    164715000.0              8875.69
# 28    349807000.0             11382.87
# 29     17738000.0              9789.18
# 30      6682000.0             13179.49
# 31      7755000.0              9503.68
# 32            0.0                  NaN
# 33     14897000.0                  inf
# 34    288343000.0             12067.09

# %%
df_enrollment_revenue.tail(35)
# Out:
#                           Agency Name   Black  Hispanic    White  \
# 1126        WESTSIDE UNION ELEMENTARY   986.0    4167.0   3206.0
# 1127                 WESTWOOD UNIFIED     5.0      54.0    248.0
# 1128                        WHEATLAND    63.0     299.0    781.0
# 1129             WHEATLAND UNION HIGH    25.0     223.0    364.0
# 1130        WHITMORE UNION ELEMENTARY     3.0      25.0    159.0
# 1131         WHITTIER CITY ELEMENTARY    40.0    5574.0    230.0
# 1132              WHITTIER UNION HIGH   105.0   10604.0    968.0
# 1133            WILLIAM (R) ROUSE ROP     0.0       0.0      0.0
# 1134       WILLIAM S. HART UNION HIGH  1275.0   10623.0  10383.0
# 1135                 WILLIAMS UNIFIED     4.0    1284.0     71.0
# 1136                  WILLITS UNIFIED    13.0     535.0   1056.0
# 1137          WILLOW CREEK ELEMENTARY     0.0       2.0     25.0
# 1138    WILLOW GROVE UNION ELEMENTARY     0.0      18.0      1.0
# 1139                  WILLOWS UNIFIED     8.0     707.0    565.0
# 1140          WILMAR UNION ELEMENTARY     0.0      40.0    179.0
# 1141               WILSONA ELEMENTARY   145.0     896.0    205.0
# 1142                  WINDSOR UNIFIED    33.0    2648.0   2253.0
# 1143                  WINSHIP-ROBBINS     2.0     245.0    395.0
# 1144            WINTERS JOINT UNIFIED    23.0    1027.0    473.0
# 1145                           WINTON    15.0    1692.0    144.0
# 1146                 WISEBURN UNIFIED   616.0    2227.0    834.0
# 1147                 WOODLAKE UNIFIED     6.0    1999.0    158.0
# 1148           WOODLAND JOINT UNIFIED   139.0    6843.0   2243.0
# 1149              WOODSIDE ELEMENTARY     9.0      45.0    283.0
# 1150       WOODVILLE UNION ELEMENTARY     0.0     426.0      9.0
# 1151                WRIGHT ELEMENTARY    47.0    1039.0    314.0
# 1152  YOLO COUNTY OFFICE OF EDUCATION     9.0     156.0    358.0
# 1153                  YOLO COUNTY ROP     0.0       0.0      0.0
# 1154                     YOSEMITE ROP     0.0       0.0      0.0
# 1155                 YOSEMITE UNIFIED    13.0     411.0   1515.0
# 1156           YREKA UNION ELEMENTARY     7.0     150.0    574.0
# 1157                 YREKA UNION HIGH     5.0      98.0    424.0
# 1158                YUBA CITY UNIFIED   244.0    5869.0   3785.0
# 1159  YUBA COUNTY OFFICE OF EDUCATION    18.0     165.0    287.0
# 1160   YUCAIPA-CALIMESA JOINT UNIFIED   153.0    4038.0   4720.0
#
#       Asian or Pacific Islander  American Indian/Alaska Native  \
# 1126                      401.0                           20.0
# 1127                        4.0                           17.0
# 1128                       47.0                           17.0
# 1129                       21.0                            9.0
# 1130                        1.0                            1.0
# 1131                       47.0                           12.0
# 1132                      256.0                           21.0
# 1133                        0.0                            0.0
# 1134                     2856.0                           83.0
# 1135                       15.0                            2.0
# 1136                       30.0                          143.0
# 1137                        0.0                            3.0
# 1138                        0.0                            0.0
# 1139                       74.0                           36.0
# 1140                        2.0                            2.0
# 1141                        4.0                           15.0
# 1142                       94.0                           56.0
# 1143                       20.0                            4.0
# 1144                       19.0                            4.0
# 1145                       76.0                           10.0
# 1146                      215.0                            9.0
# 1147                       17.0                            6.0
# 1148                      556.0                           54.0
# 1149                       15.0                            0.0
# 1150                        1.0                            0.0
# 1151                      129.0                           18.0
# 1152                        8.0                            1.0
# 1153                        0.0                            0.0
# 1154                        0.0                            0.0
# 1155                       33.0                           64.0
# 1156                       25.0                          149.0
# 1157                        8.0                           36.0
# 1158                     2538.0                           86.0
# 1159                       15.0                           20.0
# 1160                      190.0                           42.0
#
#       Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 1126                              12.0              510.0            9302.0
# 1127                               0.0               18.0             346.0
# 1128                              10.0              117.0            1334.0
# 1129                               2.0               95.0             739.0
# 1130                               1.0               26.0             216.0
# 1131                               7.0              165.0            6075.0
# 1132                              16.0               51.0           12021.0
# 1133                               0.0                0.0               0.0
# 1134                              34.0             1512.0           26766.0
# 1135                               1.0                5.0            1382.0
# 1136                               2.0              105.0            1884.0
# 1137                               0.0                9.0              39.0
# 1138                               0.0                0.0              19.0
# 1139                               5.0               29.0            1424.0
# 1140                               2.0                8.0             233.0
# 1141                               0.0               50.0            1315.0
# 1142                              17.0              122.0            5223.0
# 1143                               0.0               74.0             740.0
# 1144                               2.0                7.0            1555.0
# 1145                               0.0                5.0            1942.0
# 1146                              23.0              377.0            4301.0
# 1147                               0.0                6.0            2192.0
# 1148                              36.0              206.0           10077.0
# 1149                               7.0               41.0             400.0
# 1150                               0.0                0.0             436.0
# 1151                               4.0               42.0            1593.0
# 1152                               2.0                6.0             540.0
# 1153                               0.0                0.0               0.0
# 1154                               0.0                0.0               0.0
# 1155                               1.0              151.0            2188.0
# 1156                               0.0               54.0             959.0
# 1157                               0.0               63.0             634.0
# 1158                              44.0              718.0           13284.0
# 1159                               2.0               59.0             566.0
# 1160                              19.0              807.0            9969.0
#
#       Total Revenue  Revenue per student
# 1126     83599000.0              8987.21
# 1127      2746000.0              7936.42
# 1128     16268000.0             12194.90
# 1129      7190000.0              9729.36
# 1130      2599000.0             12032.41
# 1131     64739000.0             10656.63
# 1132    163000000.0             13559.60
# 1133            0.0                  NaN
# 1134    239609000.0              8951.99
# 1135     13664000.0              9887.12
# 1136     17217000.0              9138.54
# 1137       605000.0             15512.82
# 1138        80000.0              4210.53
# 1139     12356000.0              8676.97
# 1140      1226000.0              5261.80
# 1141     16221000.0             12335.36
# 1142     41561000.0              7957.30
# 1143      2489000.0              3363.51
# 1144     16339000.0             10507.40
# 1145     25475000.0             13117.92
# 1146     66336000.0             15423.39
# 1147     30840000.0             14069.34
# 1148     97180000.0              9643.74
# 1149     14636000.0             36590.00
# 1150      6337000.0             14534.40
# 1151     15815000.0              9927.81
# 1152     42918000.0             79477.78
# 1153            0.0                  NaN
# 1154            0.0                  NaN
# 1155     17219000.0              7869.74
# 1156      9436000.0              9839.42
# 1157      6836000.0             10782.33
# 1158    137279000.0             10334.16
# 1159     29297000.0             51761.48
# 1160     93604000.0              9389.51

# %%
#df_enrollment_revenue.info

# %% [markdown]
# ### Filter from the text file the following columns: distrtict code, district name, and zipcode

# %%
df_distcode.columns
# Out:
# Index(['County Code', 'District Code', 'School Code', 'Filler', 'Test Year',
#        'Type Id', 'County Name', 'District Name', 'School Name', 'Zip Code'],
#       dtype='object')

# %%
del_columns = ['County Code', 'School Code', 'Filler', 'Test Year', 'Type Id', 'County Name', 'School Name']
df_dist_code = df_distcode.drop(del_columns, 1)

# %%
df_del_dup = df_dist_code.drop_duplicates(['District Name'])
#df_del_dup.head()

# %%
df_sorted = df_del_dup.sort_values(by=['District Name'])
df_sorted['District Name'] = df_sorted['District Name'].str.upper()
df_sorted.head()
# Out:
#        District Code              District Name Zip Code
# 2150           64212                ABC UNIFIED
# 10231          70920            ABRAXIS CHARTER    95401
# 8630           68627  ACACIA ELEMENTARY CHARTER    95210
# 8629           68627      ACACIA MIDDLE CHARTER    95210
# 2930           64733           ACADEMIA MODERNA    90255

# %%
df_sorted['Zip Code'] = df_sorted['Zip Code'].apply(pd.to_numeric, errors='coerce')
df_sorted['Agency Name'] = df_sorted['District Name']

# %%
df_district = df_sorted[df_sorted['Zip Code'].isna()]

# %%
del df_district['Zip Code']
del df_district['District Name']

# %%
df_district.reset_index()
# Out:
#       index  District Code                      Agency Name
# 0      2150          64212                      ABC UNIFIED
# 1       611          61630              ACALANES UNION HIGH
# 2      5822          66761                 ACKERMAN CHARTER
# 3      4363          75309         ACTON-AGUA DULCE UNIFIED
# 4      6955          67587              ADELANTO ELEMENTARY
# ...     ...            ...                              ...
# 1001   9948          70516                 YREKA UNION HIGH
# 1002  10581          71464                YUBA CITY UNIFIED
# 1003  11280          10587  YUBA COUNTY OFFICE OF EDUCATION
# 1004   7433          67959   YUCAIPA-CALIMESA JOINT UNIFIED
# 1005      0              0                              NaN
#
# [1006 rows x 3 columns]

# %%
df_enrollment_revenue
# Out:
#                           Agency Name   Black  Hispanic   White  \
# 0                         ABC UNIFIED  1791.0    9425.0  1302.0
# 1                 ACALANES UNION HIGH    95.0     508.0  3622.0
# 2                    ACKERMAN CHARTER     4.0      74.0   460.0
# 3            ACTON-AGUA DULCE UNIFIED   705.0    3466.0  4199.0
# 4                 ADELANTO ELEMENTARY  2156.0    6327.0  1010.0
# ...                               ...     ...       ...     ...
# 1156           YREKA UNION ELEMENTARY     7.0     150.0   574.0
# 1157                 YREKA UNION HIGH     5.0      98.0   424.0
# 1158                YUBA CITY UNIFIED   244.0    5869.0  3785.0
# 1159  YUBA COUNTY OFFICE OF EDUCATION    18.0     165.0   287.0
# 1160   YUCAIPA-CALIMESA JOINT UNIFIED   153.0    4038.0  4720.0
#
#       Asian or Pacific Islander  American Indian/Alaska Native  \
# 0                        7459.0                           63.0
# 1                         850.0                            9.0
# 2                           9.0                            2.0
# 3                         536.0                           36.0
# 4                         139.0                           35.0
# ...                         ...                            ...
# 1156                       25.0                          149.0
# 1157                        8.0                           36.0
# 1158                     2538.0                           86.0
# 1159                       15.0                           20.0
# 1160                      190.0                           42.0
#
#       Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 0                                158.0              524.0           20722.0
# 1                                 16.0              402.0            5502.0
# 2                                  0.0               37.0             586.0
# 3                                 18.0             1040.0           10000.0
# 4                                 88.0              517.0           10272.0
# ...                                ...                ...               ...
# 1156                               0.0               54.0             959.0
# 1157                               0.0               63.0             634.0
# 1158                              44.0              718.0           13284.0
# 1159                               2.0               59.0             566.0
# 1160                              19.0              807.0            9969.0
#
#       Total Revenue  Revenue per student
# 0       226251000.0             10918.40
# 1        37710000.0              6853.87
# 2         4410000.0              7525.60
# 3        29983000.0              2998.30
# 4       120023000.0             11684.48
# ...             ...                  ...
# 1156      9436000.0              9839.42
# 1157      6836000.0             10782.33
# 1158    137279000.0             10334.16
# 1159     29297000.0             51761.48
# 1160     93604000.0              9389.51
#
# [1161 rows x 11 columns]

# %% [markdown]
# ### Merging the two main datasets:

# %%
df_merged_district = pd.merge(df_district, df_enrollment_revenue)
df_merged_district.head(50)
# Out:
#     District Code                         Agency Name   Black  Hispanic  \
# 0           64212                         ABC UNIFIED  1791.0    9425.0
# 1           61630                 ACALANES UNION HIGH    95.0     508.0
# 2           66761                    ACKERMAN CHARTER     4.0      74.0
# 3           75309            ACTON-AGUA DULCE UNIFIED   705.0    3466.0
# 4           67587                 ADELANTO ELEMENTARY  2156.0    6327.0
# 5           10017  ALAMEDA COUNTY OFFICE OF EDUCATION   543.0    1581.0
# 6           61119                     ALAMEDA UNIFIED   924.0    1897.0
# 7           61127                 ALBANY CITY UNIFIED   117.0     603.0
# 8           70599   ALEXANDER VALLEY UNION ELEMENTARY     1.0      48.0
# 9           75713                    ALHAMBRA UNIFIED   112.0    7071.0
# 10          65961                        ALISAL UNION    34.0    8414.0
# 11          71795              ALLENSWORTH ELEMENTARY     1.0      77.0
# 12          71803                     ALPAUGH UNIFIED    16.0     501.0
# 13          61333               ALPINE COUNTY UNIFIED     0.0       4.0
# 14          67967             ALPINE UNION ELEMENTARY    37.0     400.0
# 15          67595                ALTA LOMA ELEMENTARY   381.0    2676.0
# 16          71811               ALTA VISTA ELEMENTARY     0.0     449.0
# 17          66779    ALTA-DUTCH FLAT UNION ELEMENTARY     0.0       6.0
# 18          69369          ALUM ROCK UNION ELEMENTARY   156.0    9154.0
# 19          65177   ALVIEW-DAIRYLAND UNION ELEMENTARY     0.0     213.0
# 20          61994                   ALVINA ELEMENTARY     0.0     154.0
# 21          66977                      ALVORD UNIFIED   720.0   15161.0
# 22          10033   AMADOR COUNTY OFFICE OF EDUCATION     0.0      51.0
# 23          73981               AMADOR COUNTY UNIFIED    23.0     780.0
# 24          66423                  ANAHEIM ELEMENTARY   265.0   15961.0
# 25          66431                  ANAHEIM UNION HIGH   716.0   20555.0
# 26          69856                 ANDERSON UNION HIGH    30.0     293.0
# 27          65540             ANDERSON VALLEY UNIFIED     5.0     384.0
# 28          71472                 ANTELOPE ELEMENTARY     9.0     187.0
# 29          64246          ANTELOPE VALLEY UNION HIGH  4207.0   14647.0
# 30          61648                     ANTIOCH UNIFIED  4333.0    7533.0
# 31          75077                APPLE VALLEY UNIFIED  1287.0    6520.0
# 32          64261                     ARCADIA UNIFIED   170.0    1380.0
# 33          62679                   ARCATA ELEMENTARY    13.0     159.0
# 34          67280             ARCOHE UNION ELEMENTARY    12.0     204.0
# 35          65557              ARENA UNION ELEMENTARY     0.0     154.0
# 36          63875             ARMONA UNION ELEMENTARY    54.0    1051.0
# 37          63313                         ARVIN UNION    16.0    2902.0
# 38          68700                  ATASCADERO UNIFIED    64.0    1288.0
# 39          65631                  ATWATER ELEMENTARY   113.0    3511.0
# 40          66787             AUBURN UNION ELEMENTARY    28.0     626.0
# 41          64279                       AZUSA UNIFIED   116.0    8073.0
# 42          73858                BAKER VALLEY UNIFIED     0.0     110.0
# 43          63321                    BAKERSFIELD CITY  2422.0   23959.0
# 44          64287                BALDWIN PARK UNIFIED   564.0   14575.0
# 45          69104                  BALLARD ELEMENTARY     1.0      18.0
# 46          65649          BALLICO-CRESSEY ELEMENTARY     5.0     211.0
# 47          61382             BANGOR UNION ELEMENTARY     0.0      13.0
# 48          66985                     BANNING UNIFIED   365.0    3072.0
# 49          68486                    BANTA ELEMENTARY    23.0     357.0
#
#      White  Asian or Pacific Islander  American Indian/Alaska Native  \
# 0   1302.0                     7459.0                           63.0
# 1   3622.0                      850.0                            9.0
# 2    460.0                        9.0                            2.0
# 3   4199.0                      536.0                           36.0
# 4   1010.0                      139.0                           35.0
# 5    209.0                      263.0                           16.0
# 6   3292.0                     3722.0                           33.0
# 7   1368.0                     1080.0                            5.0
# 8     80.0                        0.0                            0.0
# 9    349.0                     9084.0                           33.0
# 10   117.0                      131.0                            4.0
# 11     0.0                        0.0                            0.0
# 12   213.0                       15.0                            4.0
# 13    42.0                        0.0                           32.0
# 14  1111.0                       35.0                           81.0
# 15  2281.0                      501.0                           31.0
# 16    76.0                        5.0                            4.0
# 17    91.0                        1.0                            1.0
# 18   194.0                     1868.0                           21.0
# 19   156.0                       10.0                            1.0
# 20    24.0                        1.0                            2.0
# 21  2034.0                      949.0                           40.0
# 22   143.0                        0.0                            9.0
# 23  2652.0                       54.0                          101.0
# 24   873.0                     1046.0                           18.0
# 25  3135.0                     5287.0                          145.0
# 26  1274.0                       49.0                          104.0
# 27   110.0                        1.0                            4.0
# 28   568.0                       11.0                           16.0
# 29  3260.0                      628.0                           77.0
# 30  2623.0                     1630.0                          104.0
# 31  5718.0                      424.0                           58.0
# 32  1290.0                     6483.0                           12.0
# 33   715.0                       19.0                           34.0
# 34   198.0                        7.0                            5.0
# 35   113.0                        0.0                           28.0
# 36   348.0                       22.0                           27.0
# 37    95.0                        7.0                            5.0
# 38  2983.0                      108.0                           47.0
# 39   969.0                      218.0                           35.0
# 40  1209.0                       49.0                           21.0
# 41   296.0                      184.0                           19.0
# 42    14.0                        0.0                            0.0
# 43  2899.0                      368.0                          150.0
# 44   577.0                     1049.0                          230.0
# 45   105.0                        3.0                            0.0
# 46   104.0                       11.0                            3.0
# 47    67.0                        0.0                            4.0
# 48   580.0                      249.0                          128.0
# 49   169.0                      177.0                            0.0
#
#     Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 0                              158.0              524.0           20722.0
# 1                               16.0              402.0            5502.0
# 2                                0.0               37.0             586.0
# 3                               18.0             1040.0           10000.0
# 4                               88.0              517.0           10272.0
# 5                               33.0              225.0            2870.0
# 6                               85.0             1206.0           11159.0
# 7                                7.0              522.0            3702.0
# 8                                0.0                1.0             130.0
# 9                               16.0              406.0           17071.0
# 10                              18.0              517.0            9235.0
# 11                               0.0                0.0              78.0
# 12                               0.0               44.0             793.0
# 13                               0.0                2.0              80.0
# 14                               7.0               74.0            1745.0
# 15                              28.0               90.0            5988.0
# 16                              19.0                2.0             555.0
# 17                               0.0                5.0             104.0
# 18                              97.0              134.0           11624.0
# 19                               0.0                1.0             381.0
# 20                               1.0                0.0             182.0
# 21                              85.0              245.0           19234.0
# 22                               0.0               19.0             222.0
# 23                               9.0              245.0            3864.0
# 24                              67.0              328.0           18558.0
# 25                             167.0              726.0           30731.0
# 26                              10.0               52.0            1812.0
# 27                               0.0                3.0             507.0
# 28                               1.0               24.0             816.0
# 29                              46.0             1030.0           23895.0
# 30                             214.0              889.0           17326.0
# 31                              72.0              291.0           14370.0
# 32                               8.0              182.0            9525.0
# 33                               3.0              121.0            1064.0
# 34                               2.0               23.0             451.0
# 35                               0.0               18.0             313.0
# 36                               2.0               38.0            1542.0
# 37                               0.0                3.0            3028.0
# 38                               5.0              132.0            4627.0
# 39                              13.0              105.0            4964.0
# 40                               2.0              100.0            2035.0
# 41                               1.0               56.0            8745.0
# 42                               0.0                0.0             124.0
# 43                              37.0              537.0           30372.0
# 44                              41.0              697.0           17733.0
# 45                               0.0                2.0             129.0
# 46                               0.0               39.0             373.0
# 47                               0.0                3.0              87.0
# 48                               7.0              140.0            4541.0
# 49                               4.0               40.0             770.0
#
#     Total Revenue  Revenue per student
# 0     226251000.0             10918.40
# 1      37710000.0              6853.87
# 2       4410000.0              7525.60
# 3      29983000.0              2998.30
# 4     120023000.0             11684.48
# 5      55795000.0             19440.77
# 6      96642000.0              8660.45
# 7      58211000.0             15724.20
# 8       1123000.0              8638.46
# 9     250138000.0             14652.80
# 10    109541000.0             11861.51
# 11      1105000.0             14166.67
# 12      5021000.0              6331.65
# 13      1714000.0             21425.00
# 14     13433000.0              7697.99
# 15     55109000.0              9203.24
# 16      7103000.0             12798.20
# 17       794000.0              7634.62
# 18    113219000.0              9740.11
# 19      3352000.0              8797.90
# 20      1769000.0              9719.78
# 21    222608000.0             11573.67
# 22     12859000.0             57923.42
# 23     17515000.0              4532.87
# 24    164715000.0              8875.69
# 25    349807000.0             11382.87
# 26     17738000.0              9789.18
# 27      6682000.0             13179.49
# 28      7755000.0              9503.68
# 29    288343000.0             12067.09
# 30    167684000.0              9678.17
# 31    140868000.0              9802.92
# 32     77631000.0              8150.24
# 33     11841000.0             11128.76
# 34      4052000.0              8984.48
# 35            0.0                 0.00
# 36     14613000.0              9476.65
# 37     40148000.0             13258.92
# 38     28220000.0              6098.98
# 39     60592000.0             12206.29
# 40     15804000.0              7766.09
# 41    115452000.0             13202.06
# 42       964000.0              7774.19
# 43    380895000.0             12540.99
# 44    200607000.0             11312.64
# 45       640000.0              4961.24
# 46      3684000.0              9876.68
# 47      1125000.0             12931.03
# 48     53443000.0             11768.99
# 49      7016000.0              9111.69

# %%
df_merged_district.loc[df_merged_district['District Code'] == 10157]
# Out:
#      District Code                      Agency Name  Black  Hispanic   White  \
# 397          10157  KERN COUNTY OFFICE OF EDUCATION  257.0    2855.0  1092.0
#
#      Asian or Pacific Islander  American Indian/Alaska Native  \
# 397                       81.0                           25.0
#
#      Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 397                               6.0               73.0            4389.0
#
#      Total Revenue  Revenue per student
# 397    303202000.0             69082.25

# %%
df_merged_district.to_csv('total_enrollment_per_race_with_districtcode.csv')

# %%
# Need to clean missing data, outliers, etc as we can see below

df_merged_district.sort_values(by=['Revenue per student'])
# Out:
#      District Code                           Agency Name  Black  Hispanic  \
# 540          71175                     MODESTO CITY HIGH  537.0    8547.0
# 812          77032                SBE - AUDEO CHARTER II    6.0     173.0
# 539          71167               MODESTO CITY ELEMENTARY  364.0   10546.0
# 813          76547            SBE - BARACK OBAMA CHARTER  211.0     134.0
# 814          76943    SBE - BAYPOINT PREPARATORY ACADEMY   25.0     171.0
# ..             ...                                   ...    ...       ...
# 777          10413  SAN MATEO COUNTY OFFICE OF EDUCATION    9.0     115.0
# 440          10181     LASSEN COUNTY OFFICE OF EDUCATION    1.0       1.0
# 177          10066     COLUSA COUNTY OFFICE OF EDUCATION    0.0       2.0
# 413          71142              KNIGHTS FERRY ELEMENTARY    0.0       0.0
# 916          67892                   TRONA JOINT UNIFIED    0.0       0.0
#
#       White  Asian or Pacific Islander  American Indian/Alaska Native  \
# 540  4067.0                      948.0                           57.0
# 812    89.0                        3.0                            0.0
# 539  2501.0                      673.0                           57.0
# 813     3.0                        1.0                            1.0
# 814   164.0                       12.0                            1.0
# ..      ...                        ...                            ...
# 777    41.0                       53.0                            0.0
# 440     9.0                        0.0                            0.0
# 177     1.0                        0.0                            0.0
# 413     0.0                        0.0                            0.0
# 916     0.0                        0.0                            0.0
#
#      Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 540                             135.0             1097.0           15388.0
# 812                               2.0               14.0             287.0
# 539                              87.0             1102.0           15330.0
# 813                               0.0                5.0             355.0
# 814                               1.0                9.0             383.0
# ..                                ...                ...               ...
# 777                              12.0               10.0             240.0
# 440                               0.0                2.0              13.0
# 177                               0.0                1.0               4.0
# 413                               0.0                0.0               0.0
# 916                               0.0                0.0               0.0
#
#      Total Revenue  Revenue per student
# 540            0.0                 0.00
# 812            0.0                 0.00
# 539            0.0                 0.00
# 813            0.0                 0.00
# 814            0.0                 0.00
# ..             ...                  ...
# 777    164683000.0            686179.17
# 440     11513000.0            885615.38
# 177     11679000.0           2919750.00
# 413       965000.0                  inf
# 916      8846000.0                  inf
#
# [1005 rows x 12 columns]

# %% [markdown]
# ----------

# %% [markdown]
# # Exploratory Data Analysis - EDA

# %% [markdown]
# ### In statistics, exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods. A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.

# %%
df_merged_district.shape
# Out:
# (1005, 12)

# %% [markdown]
# In 2019-2020 there was 1,037 school districts in California. See the California Department of Education article below.
# https://www.cde.ca.gov/ds/sd/cb/ceffingertipfacts.asp
#
# It appears that in 2015 there was around 977 school districts in California. See article from Ballotpedia.
# https://ballotpedia.org/List_of_school_districts_in_California
#
# Our dataset got 1005 school districts which so far appears to be a reasonable expectation for the year of 2017.

# %%
# checking for NaNs
df_merged_district.isna().sum()
# Out:
# District Code                       0
# Agency Name                         0
# Black                               0
# Hispanic                            0
# White                               0
# Asian or Pacific Islander           0
# American Indian/Alaska Native       0
# Hawaiian Native/Pacific Islander    0
# Two or More Races                   0
# Total Enrollment                    0
# Total Revenue                       0
# Revenue per student                 0
# dtype: int64

# %%
df_merged_district['Revenue per student'] = df_merged_district['Revenue per student'].replace(np.inf, np.nan)

# %%
df_merged_district['Revenue per student'].isna().sum()
# Out:
# 2

# %%
df_district = df_merged_district.dropna()
df_district['Revenue per student'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Exploring REVENUE PER STUDENT

# %%
# the standard deviation indicates that there's likely very large values on the column 'Revenue per student'
# Probably because we have missing data for total enrollment
# We need to clean the dataset -- one way is to drop 

mean = np.mean(df_district['Revenue per student'])
std = np.std(df_district['Revenue per student'])
median = np.median(df_district['Revenue per student'])

print('mean: ', mean)
print('standard deviation: ', std)
print('median: ', median)
# Out:
# mean:  20378.265852442713
# standard deviation:  105212.65096563658
# median:  9795.73

# %%
# counts the number of zeroes per row in the dataset
df_district.isin([0]).sum()
# Out:
# District Code                         0
# Agency Name                           0
# Black                               160
# Hispanic                              6
# White                                 6
# Asian or Pacific Islander           132
# American Indian/Alaska Native       137
# Hawaiian Native/Pacific Islander    321
# Two or More Races                    46
# Total Enrollment                      0
# Total Revenue                        21
# Revenue per student                  21
# dtype: int64

# %% [markdown]
# Q: There are 21 rows containing zeroes for Total Revenue, consequently for Revenue per student -- we could perhaps input the median for revenue per student for these?
#
# ---------

# %%
# replace zeroes in revenueper student with the median
df_district['Revenue per student'].replace(to_replace=0, value = df_district['Revenue per student'].median(), inplace = True)

#df_district['Revenue per student'] = df_district['Revenue per student'].replace(0, 9795.73)
# Out:
# /Users/gabriellewald/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4569: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
df_district.isin([0]).sum()
# Out:
# District Code                         0
# Agency Name                           0
# Black                               160
# Hispanic                              6
# White                                 6
# Asian or Pacific Islander           132
# American Indian/Alaska Native       137
# Hawaiian Native/Pacific Islander    321
# Two or More Races                    46
# Total Enrollment                      0
# Total Revenue                        21
# Revenue per student                   0
# dtype: int64

# %%
df_district['Revenue per student'].sort_values(ascending=False)
# Out:
# 177    2919750.00
# 440     885615.38
# 777     686179.17
# 425     542441.18
# 763     472842.54
#           ...
# 504       1650.05
# 530       1377.98
# 503       1004.97
# 317        583.70
# 702        571.21
# Name: Revenue per student, Length: 1003, dtype: float64

# %%
# need to figure this out
data = df_district['Revenue per student']
binwidth = (data.max() - data.min()) / 10
df_district.hist(column='Revenue per student', bins=np.arange(min(data), max(data) + binwidth, binwidth))
# Out:
# array([[<AxesSubplot:title={'center':'Revenue per student'}>]],
#       dtype=object)

# %%
_ = plt.hist(df_district['Revenue per student'], bins=5)

# %% [markdown]
# ### Exploring TOTAL ENROLLMENT

# %%
# what's the total enrollment

mean = np.mean(df_district['Total Enrollment'])
std = np.std(df_district['Total Enrollment'])
median = np.median(df_district['Total Enrollment'])

print('mean: ', mean)
print('standard deviation: ', std)
print('median: ', median)
# Out:
# mean:  6187.547357926222
# standard deviation:  22190.95937144281
# median:  1884.0

# %%
df_district['Total Enrollment'].sort_values(ascending=True)
# Out:
# 177         4.0
# 649         6.0
# 169         7.0
# 277        10.0
# 80         11.0
#          ...
# 243     62552.0
# 292     73356.0
# 474     76428.0
# 761    128040.0
# 479    633621.0
# Name: Total Enrollment, Length: 1003, dtype: float64

# %%
# Need to figure this out


_ = plt.hist(df_district['Total Enrollment'], bins = 50)

# %%
df_district
# Out:
#       District Code                      Agency Name   Black  Hispanic  \
# 0             64212                      ABC UNIFIED  1791.0    9425.0
# 1             61630              ACALANES UNION HIGH    95.0     508.0
# 2             66761                 ACKERMAN CHARTER     4.0      74.0
# 3             75309         ACTON-AGUA DULCE UNIFIED   705.0    3466.0
# 4             67587              ADELANTO ELEMENTARY  2156.0    6327.0
# ...             ...                              ...     ...       ...
# 1000          70508           YREKA UNION ELEMENTARY     7.0     150.0
# 1001          70516                 YREKA UNION HIGH     5.0      98.0
# 1002          71464                YUBA CITY UNIFIED   244.0    5869.0
# 1003          10587  YUBA COUNTY OFFICE OF EDUCATION    18.0     165.0
# 1004          67959   YUCAIPA-CALIMESA JOINT UNIFIED   153.0    4038.0
#
#        White  Asian or Pacific Islander  American Indian/Alaska Native  \
# 0     1302.0                     7459.0                           63.0
# 1     3622.0                      850.0                            9.0
# 2      460.0                        9.0                            2.0
# 3     4199.0                      536.0                           36.0
# 4     1010.0                      139.0                           35.0
# ...      ...                        ...                            ...
# 1000   574.0                       25.0                          149.0
# 1001   424.0                        8.0                           36.0
# 1002  3785.0                     2538.0                           86.0
# 1003   287.0                       15.0                           20.0
# 1004  4720.0                      190.0                           42.0
#
#       Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 0                                158.0              524.0           20722.0
# 1                                 16.0              402.0            5502.0
# 2                                  0.0               37.0             586.0
# 3                                 18.0             1040.0           10000.0
# 4                                 88.0              517.0           10272.0
# ...                                ...                ...               ...
# 1000                               0.0               54.0             959.0
# 1001                               0.0               63.0             634.0
# 1002                              44.0              718.0           13284.0
# 1003                               2.0               59.0             566.0
# 1004                              19.0              807.0            9969.0
#
#       Total Revenue  Revenue per student
# 0       226251000.0             10918.40
# 1        37710000.0              6853.87
# 2         4410000.0              7525.60
# 3        29983000.0              2998.30
# 4       120023000.0             11684.48
# ...             ...                  ...
# 1000      9436000.0              9839.42
# 1001      6836000.0             10782.33
# 1002    137279000.0             10334.16
# 1003     29297000.0             51761.48
# 1004     93604000.0              9389.51
#
# [1003 rows x 12 columns]

# %% [markdown]
# ### Exploring TOTAL REVENUE

# %%
# Is the result in millions???

mean = np.mean(df_district['Total Enrollment'])
std = np.std(df_district['Total Enrollment'])
median = np.median(df_district['Total Enrollment'])

print('mean: ', mean)
print('standard deviation: ', std)
print('median: ', median)
# Out:
# mean:  6187.547357926222
# standard deviation:  22190.95937144281
# median:  1884.0
