# %%
# Load packages
import os
import pandas as pd
import numpy as np

# This line is needed to display plots inline in Jupyter Notebook
# %matplotlib inline

# Required for basic python plotting functionality
import matplotlib.pyplot as plt

# Required for formatting dates later in the case
import datetime
import matplotlib.dates as mdates

# Required to display image inline
from IPython.display import Image

# Advanced plotting functionality with seaborn
import seaborn as sns

sns.set(style="whitegrid")  # can set style depending on how you'd like it to look

# %%
df = pd.read_csv("total_enrollment_per_race_with_districtcode.csv")

# %%
DFass=pd.read_csv('ethnicity_new.csv') #Students by ethnicity data

# %%
#DFassall=pd.read_csv('all_assessment.csv') #All students assessment data

# %%
DFass.head(2)
# Out:
#    County Code  District Code  Subgroup ID  Test Id  \
# 0            1          10017           74        1
# 1            1          10017           74        2
#
#    Total Tested At Entity Level  Total Tested with Scores  \
# 0                         105.0                     105.0
# 1                         115.0                     115.0
#
#    CAASPP Reported Enrollment  Students Tested  Total Standard Exceeded  \
# 0                       157.0             41.0                      0.0
# 1                       157.0             45.0                      0.0
#
#    Mean Scale Score  Total Standard Met  Total Standard Nearly Met  \
# 0            2419.6                 0.0                        6.0
# 1            2403.7                 0.0                        0.0
#
#    Total Standard Not Met  Students with Scores  Total Standard Met and Above
# 0                    35.0                  41.0                           0.0
# 1                    45.0                  45.0                           0.0

# %%
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=74, value='Black')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=75, value='American Indian/Alaska Native')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=76, value='Asian or Pacific Islander')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=77, value='Filipino')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=78, value='Hispanic')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=79, value='Hawaiian Native/Pacific Islander')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=80, value='White')
DFass['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=144, value='Two or More Races')

# %%
#DFassall['Subgroup ID']=DFassall['Subgroup ID'].replace(to_replace=74, value='Black')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=75, value='American Indian/Alaska Native')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=76, value='Asian or Pacific Islander')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=77, value='Filipino')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=78, value='Hispanic')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=79, value='Hawaiian Native/Pacific Islander')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=80, value='White')
#DFassall['Subgroup ID']=DFass['Subgroup ID'].replace(to_replace=144, value='Two or More Races')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'District Code', 'Agency Name', 'Black', 'Hispanic',
#        'White', 'Asian or Pacific Islander', 'American Indian/Alaska Native',
#        'Hawaiian Native/Pacific Islander', 'Two or More Races',
#        'Total Enrollment', 'Total Revenue', 'Revenue per student'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Unnamed: 0  District Code          Agency Name   Black  Hispanic   White  \
# 0           0          64212          ABC UNIFIED  1791.0    9425.0  1302.0
# 1           1          61630  ACALANES UNION HIGH    95.0     508.0  3622.0
#
#    Asian or Pacific Islander  American Indian/Alaska Native  \
# 0                     7459.0                           63.0
# 1                      850.0                            9.0
#
#    Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# 0                             158.0              524.0           20722.0
# 1                              16.0              402.0            5502.0
#
#    Total Revenue  Revenue per student
# 0    226251000.0             10918.40
# 1     37710000.0              6853.87

# %%
#Melt the data to have each ethnicity 
DFfinMelt = pd.melt(df, id_vars=['District Code', 'Agency Name', 'Total Enrollment', 'Total Revenue', 'Revenue per student'], 
        value_vars=['Black', 'Hispanic', 'White', 'Asian or Pacific Islander',
       'American Indian/Alaska Native', 'Hawaiian Native/Pacific Islander','Two or More Races'])

# %%
DFfinMelt.head(2)
# Out:
#    District Code          Agency Name  Total Enrollment  Total Revenue  \
# 0          64212          ABC UNIFIED           20722.0    226251000.0
# 1          61630  ACALANES UNION HIGH            5502.0     37710000.0
#
#    Revenue per student variable   value
# 0             10918.40    Black  1791.0
# 1              6853.87    Black    95.0

# %%
#Rename col names to match the DFass
DFfinMelt.columns = ['District Code', 'Agency Name', 'Total Enrollment', 'Total Revenue','Revenue per student', 'Subgroup ID', 'Count Enrollment per ethnicity']

# %%
DFfinMelt.head(10)
# Out:
#    District Code                         Agency Name  Total Enrollment  \
# 0          64212                         ABC UNIFIED           20722.0
# 1          61630                 ACALANES UNION HIGH            5502.0
# 2          66761                    ACKERMAN CHARTER             586.0
# 3          75309            ACTON-AGUA DULCE UNIFIED           10000.0
# 4          67587                 ADELANTO ELEMENTARY           10272.0
# 5          10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 6          61119                     ALAMEDA UNIFIED           11159.0
# 7          61127                 ALBANY CITY UNIFIED            3702.0
# 8          70599   ALEXANDER VALLEY UNION ELEMENTARY             130.0
# 9          75713                    ALHAMBRA UNIFIED           17071.0
#
#    Total Revenue  Revenue per student Subgroup ID  \
# 0    226251000.0             10918.40       Black
# 1     37710000.0              6853.87       Black
# 2      4410000.0              7525.60       Black
# 3     29983000.0              2998.30       Black
# 4    120023000.0             11684.48       Black
# 5     55795000.0             19440.77       Black
# 6     96642000.0              8660.45       Black
# 7     58211000.0             15724.20       Black
# 8      1123000.0              8638.46       Black
# 9    250138000.0             14652.80       Black
#
#    Count Enrollment per ethnicity
# 0                          1791.0
# 1                            95.0
# 2                             4.0
# 3                           705.0
# 4                          2156.0
# 5                           543.0
# 6                           924.0
# 7                           117.0
# 8                             1.0
# 9                           112.0

# %%
final_ethnicity_merged = pd.merge(DFfinMelt, DFass, how='outer', on=['District Code', 'Subgroup ID'])
final_ethnicity_merged= final_ethnicity_merged.sort_values(by=['District Code'])

# %%
#final_ethnicity_merged.to_csv('final_merged.csv')
final_ethnicity_merged.head(10)
# Out:
#        District Code                         Agency Name  Total Enrollment  \
# 1799           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 11010          10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 1800           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 9401           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 9402           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 5797           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 5796           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 3797           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 3796           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 12901          10017                                 NaN               NaN
#
#        Total Revenue  Revenue per student                       Subgroup ID  \
# 1799      55795000.0             19440.77                          Hispanic
# 11010     55795000.0             19440.77                 Two or More Races
# 1800      55795000.0             19440.77                          Hispanic
# 9401      55795000.0             19440.77  Hawaiian Native/Pacific Islander
# 9402      55795000.0             19440.77  Hawaiian Native/Pacific Islander
# 5797      55795000.0             19440.77         Asian or Pacific Islander
# 5796      55795000.0             19440.77         Asian or Pacific Islander
# 3797      55795000.0             19440.77                             White
# 3796      55795000.0             19440.77                             White
# 12901            NaN                  NaN                          Filipino
#
#        Count Enrollment per ethnicity  County Code  Test Id  \
# 1799                           1581.0          1.0      1.0
# 11010                           225.0          1.0      2.0
# 1800                           1581.0          1.0      2.0
# 9401                             33.0          1.0      1.0
# 9402                             33.0          1.0      2.0
# 5797                            263.0          1.0      2.0
# 5796                            263.0          1.0      1.0
# 3797                            209.0          1.0      2.0
# 3796                            209.0          1.0      1.0
# 12901                             NaN          1.0      1.0
#
#        Total Tested At Entity Level  Total Tested with Scores  \
# 1799                           75.0                      75.0
# 11010                           0.0                       0.0
# 1800                          100.0                     100.0
# 9401                            0.0                       0.0
# 9402                            0.0                       0.0
# 5797                            0.0                       0.0
# 5796                            0.0                       0.0
# 3797                            0.0                       0.0
# 3796                            0.0                       0.0
# 12901                           0.0                       0.0
#
#        CAASPP Reported Enrollment  Students Tested  Total Standard Exceeded  \
# 1799                        109.0             27.0                      0.0
# 11010                         0.0              0.0                      0.0
# 1800                        110.0             36.0                      0.0
# 9401                          0.0              0.0                      0.0
# 9402                          0.0              0.0                      0.0
# 5797                          0.0              0.0                      0.0
# 5796                          0.0              0.0                      0.0
# 3797                          0.0              0.0                      0.0
# 3796                          0.0              0.0                      0.0
# 12901                         0.0              0.0                      0.0
#
#        Mean Scale Score  Total Standard Met  Total Standard Nearly Met  \
# 1799             2464.9                 2.0                        8.0
# 11010               0.0                 0.0                        0.0
# 1800             2431.3                 0.0                        2.0
# 9401                0.0                 0.0                        0.0
# 9402                0.0                 0.0                        0.0
# 5797                0.0                 0.0                        0.0
# 5796                0.0                 0.0                        0.0
# 3797                0.0                 0.0                        0.0
# 3796                0.0                 0.0                        0.0
# 12901               0.0                 0.0                        0.0
#
#        Total Standard Not Met  Students with Scores  \
# 1799                     17.0                  27.0
# 11010                     0.0                   0.0
# 1800                     34.0                  36.0
# 9401                      0.0                   0.0
# 9402                      0.0                   0.0
# 5797                      0.0                   0.0
# 5796                      0.0                   0.0
# 3797                      0.0                   0.0
# 3796                      0.0                   0.0
# 12901                     0.0                   0.0
#
#        Total Standard Met and Above
# 1799                            2.0
# 11010                           0.0
# 1800                            0.0
# 9401                            0.0
# 9402                            0.0
# 5797                            0.0
# 5796                            0.0
# 3797                            0.0
# 3796                            0.0
# 12901                           0.0

# %%
# Pointing out these - we should decide what to do w/them.
final_ethnicity_merged['Agency Name'].isna().sum()
# Out:
# 1594

# %%
final_ethnicity_merged['District Code'].unique().size
# Out:
# 1017

# %%
one_county = final_ethnicity_merged.copy()
#display(one_county.__class__)
one_county = one_county[one_county['Agency Name'] == 'ALAMEDA COUNTY OFFICE OF EDUCATION']
one_county_math = one_county[one_county['Test Id'] == 1.0]

# %%
one_county_math
# Out:
#        District Code                         Agency Name  Total Enrollment  \
# 1799           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 9401           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 5796           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 3796           10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 11009          10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
# 10             10017  ALAMEDA COUNTY OFFICE OF EDUCATION            2870.0
#
#        Total Revenue  Revenue per student                       Subgroup ID  \
# 1799      55795000.0             19440.77                          Hispanic
# 9401      55795000.0             19440.77  Hawaiian Native/Pacific Islander
# 5796      55795000.0             19440.77         Asian or Pacific Islander
# 3796      55795000.0             19440.77                             White
# 11009     55795000.0             19440.77                 Two or More Races
# 10        55795000.0             19440.77                             Black
#
#        Count Enrollment per ethnicity  County Code  Test Id  \
# 1799                           1581.0          1.0      1.0
# 9401                             33.0          1.0      1.0
# 5796                            263.0          1.0      1.0
# 3796                            209.0          1.0      1.0
# 11009                           225.0          1.0      1.0
# 10                              543.0          1.0      1.0
#
#        Total Tested At Entity Level  Total Tested with Scores  \
# 1799                           75.0                      75.0
# 9401                            0.0                       0.0
# 5796                            0.0                       0.0
# 3796                            0.0                       0.0
# 11009                           0.0                       0.0
# 10                            105.0                     105.0
#
#        CAASPP Reported Enrollment  Students Tested  Total Standard Exceeded  \
# 1799                        109.0             27.0                      0.0
# 9401                          0.0              0.0                      0.0
# 5796                          0.0              0.0                      0.0
# 3796                          0.0              0.0                      0.0
# 11009                         0.0              0.0                      0.0
# 10                          157.0             41.0                      0.0
#
#        Mean Scale Score  Total Standard Met  Total Standard Nearly Met  \
# 1799             2464.9                 2.0                        8.0
# 9401                0.0                 0.0                        0.0
# 5796                0.0                 0.0                        0.0
# 3796                0.0                 0.0                        0.0
# 11009               0.0                 0.0                        0.0
# 10               2419.6                 0.0                        6.0
#
#        Total Standard Not Met  Students with Scores  \
# 1799                     17.0                  27.0
# 9401                      0.0                   0.0
# 5796                      0.0                   0.0
# 3796                      0.0                   0.0
# 11009                     0.0                   0.0
# 10                       35.0                  41.0
#
#        Total Standard Met and Above
# 1799                            2.0
# 9401                            0.0
# 5796                            0.0
# 3796                            0.0
# 11009                           0.0
# 10                              0.0

# %%
one_county_math.plot(x = 'Subgroup ID', y = 'Total Standard Met', kind="bar")

# %%
test = one_county_math.groupby('District Code').sum()

# %%
test
# Out:
#                Total Enrollment  Total Revenue  Revenue per student  \
# District Code
# 10017                   17220.0    334770000.0            116644.62
#
#                Count Enrollment per ethnicity  County Code  Test Id  \
# District Code
# 10017                                  2854.0          6.0      6.0
#
#                Total Tested At Entity Level  Total Tested with Scores  \
# District Code
# 10017                                 180.0                     180.0
#
#                CAASPP Reported Enrollment  Students Tested  \
# District Code
# 10017                               266.0             68.0
#
#                Total Standard Exceeded  Mean Scale Score  Total Standard Met  \
# District Code
# 10017                              0.0            4884.5                 2.0
#
#                Total Standard Nearly Met  Total Standard Not Met  \
# District Code
# 10017                               14.0                    52.0
#
#                Students with Scores  Total Standard Met and Above
# District Code
# 10017                          68.0                           2.0
